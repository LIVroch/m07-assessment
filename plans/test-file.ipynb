# %%
import datetime
import json
from bs4 import BeautifulSoup
import requests
from dataclasses import dataclass
from config import api_key

@dataclass
class Holiday:
    name: str
    date: datetime
    
    def __str__(self):
        return f"{self.name} ({self.date.isoformat()})"

    def __gt__(self, other):
        return self.date > other.date
    
    def __ge__(self, other):
        return self.date >= other.date

    def __eq__(self, other):
        return self.date == other.date

class Holiday_List:
    def __init__(self):
       self.inner_holidays = []

    def find_holiday(self, holiday_name, date):
        # Find Holiday instance in inner_holidays
        index = self.inner_holidays.index(Holiday(holiday_name, date.datetime()))
        # Return Holiday instance
        return self.inner_holidays[index]

    def remove_holiday(self, index):
        # Find the Holiday instance's index in inner_holidays by passing find_holiday as a parameter
        # Remove the Holiday instance from inner_holidays
        self.inner_holidays.remove(index)
        # Inform user you deleted the holiday
        print(f"\n{index} has been removed from the list.\n")

    def add_holiday(self, holiday_obj):
        # Make sure holidayObj is an Holiday Object by checking the type
        if type(holiday_obj) == Holiday:
            # Use inner_holidays.append(holidayObj) to add holiday
            self.inner_holidays.append(holiday_obj)
            # print to the user that you added a holiday
            print(f"\n{holiday_obj} has been added to the list.\n")
        else:
            print(f"\nInvalid parameter, {holiday_obj} is not a Holiday object.\n")

    def scrape_holidays(self):
        # Scrape Holidays from https://www.timeanddate.com/holidays/us/ 
        months = {"Jan": "1", "Feb": "2", "Mar": "3", "Apr": "4", "May": "5", "Jun": "6", 
                    "Jul": "7", "Aug": "8", "Sep": "9", "Oct": "10", "Nov": "11", "Dec": "12"}
        for year in range(2020, 2025):
            url = f"https://www.timeanddate.com/holidays/us/{year}"
            res = requests.get(url)
            soup = BeautifulSoup(res.text, "html.parser")
            table = soup.find("section", attrs={"class":"table-data__table"}).find("tbody")
            rows = table.find_all("tr")
            for i in range(1, len(rows)):
                try:
                    name = rows[i].find("a").text
                    scraped_date = rows[i].find("th").text
                    space = scraped_date.find(" ")
                    scraped_month = scraped_date[:space]
                    month = scraped_month.replace(scraped_month, months[scraped_month])
                    day = scraped_date[space+1:]
                    date = datetime.date(year, int(month), int(day))
                    holiday = Holiday(name, date)
                    # Check to see if name and date of holiday is in inner_holidays array
                    if holiday not in self.inner_holidays:
                        # Add non-duplicates to inner_holidays
                        self.add_holiday(holiday)
                # Handle any exceptions
                except AttributeError:
                    pass

    def filter_week(self, year, week_num):
        hols_in_year = list(filter(lambda hol: hol.date.isocalendar().year == year, self.inner_holidays))
        # Use a Lambda function to filter by week number and save this as holidays, use the filter on inner_holidays
        hols_in_week = filter(lambda hol: hol.date.isocalendar().week == week_num, hols_in_year)
        # Cast filter results as list
        holidays = list(hols_in_week)
        # return your holidays
        return holidays

    def display_week(self, holiday_list):
        # Use your filter_week to get list of holidays within a week as a parameter
        # Output formated holidays in the week. 
        for holiday in range(len(holiday_list)):
            print(str(holiday_list[holiday]))

    def get_weather(self, year, week_num):
        # Convert week_num to range between two days
        week = f"{year}-W{week_num}"
        week_mon = datetime.datetime.strptime(week + '-1', "%Y-W%W-%w").date().__str__()
        week_sun = datetime.datetime.strptime(week + '-0', "%Y-W%W-%w").date().__str__()
        # Use Try / Except to catch problems
        # Query API for weather in that week range
        url = f"https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/Milwaukee/{week_mon}/{week_sun}?unitGroup=us&key={api_key}&contentType=json"
        json = requests.get(url).json()
        days = json['days']
        weather = {}
        for day in days:
            date = day['datetime']
            cond = day['conditions']
            weather[date] = cond
        # Format weather information and return weather list
        return weather

    def viewCurrentWeek(self):
        # Use the Datetime Module to look up current week and year
        today = datetime.date.today()
        curr_year = today.year
        curr_week = today.isocalendar().week
        # Use your filter_week function to get the list of holidays for the current week/year
        filt_hol = self.filter_week(curr_year, curr_week)
        # Ask user if they want to get the weather
        weather_prompt = input("Would you like to see this week's weather? [y/n]: ")
        print("\nThese are the holidays for this week: ")
        valid = 'n'
        while valid == 'n':  
            if weather_prompt == 'n':
                valid = 'y'
                # Use your display_week function to display the holidays in the week
                self.display_week(filt_hol)
            elif weather_prompt == 'y':
                valid = 'y'
                # If yes, use your getWeather function and display results
                weather = self.get_weather(curr_year, curr_week)
                for hol in filt_hol:
                    print(f"{str(hol)} - {weather[hol.date.__str__()]}")
            else:
                print("Invalid input, expecting 'y' or 'n'.")

# %%
hol_list = Holiday_List()
hol_list.scrape_holidays()
# Out:
# New Year's Day (2020-01-01) has been added to the list.
#
#
# World Braille Day (2020-01-04) has been added to the list.
#
#
# Epiphany (2020-01-06) has been added to the list.
#
#
# Asarah B'Tevet (2020-01-07) has been added to the list.
#
#
# Battle of New Orleans (2020-01-08) has been added to the list.
#
#
# Stephen Foster Memorial Day (2020-01-13) has been added to the list.
#
#
# Orthodox New Year (2020-01-14) has been added to the list.
#
#
# Lee-Jackson Day (2020-01-17) has been added to the list.
#
#
# World Religion Day (2020-01-19) has been added to the list.
#
#
# Martin Luther King Jr. Day (2020-01-20) has been added to the list.
#
#
# International Day of Education (2020-01-24) has been added to the list.
#
#
# Lunar New Year (2020-01-25) has been added to the list.
#
#
# International Customs Day (2020-01-26) has been added to the list.
#
#
# International Day of Commemoration in Memory of the Victims of the Holocaust (2020-01-27) has been added to the list.
#
#
# Kansas Day (2020-01-29) has been added to the list.
#
#
# National Freedom Day (2020-02-01) has been added to the list.
#
#
# World Wetlands Day (2020-02-02) has been added to the list.
#
#
# World Cancer Day (2020-02-04) has been added to the list.
#
#
# National Girls and Women in Sports Day (2020-02-05) has been added to the list.
#
#
# International Day of Zero Tolerance for Female Genital Mutilation (2020-02-06) has been added to the list.
#
#
# National Wear Red Day (2020-02-07) has been added to the list.
#
#
# Tu Bishvat/Tu B'Shevat (2020-02-10) has been added to the list.
#
#
# International Day of Women and Girls in Science (2020-02-11) has been added to the list.
#
#
# Lincoln's Birthday (2020-02-12) has been added to the list.
#
#
# World Radio Day (2020-02-13) has been added to the list.
#
#
# Valentine's Day (2020-02-14) has been added to the list.
#
#
# Susan B. Anthony's Birthday (2020-02-15) has been added to the list.
#
#
# Elizabeth Peratrovich Day (2020-02-16) has been added to the list.
#
#
# Presidents' Day (2020-02-17) has been added to the list.
#
#
# World Day of Social Justice (2020-02-20) has been added to the list.
#
#
# Maha Shivaratri (2020-02-21) has been added to the list.
#
#
# African-American Scientist and Inventor Day (2020-02-25) has been added to the list.
#
#
# Ash Wednesday (2020-02-26) has been added to the list.
#
#
# Linus Pauling Day (2020-02-28) has been added to the list.
#
#
# Leap Day (2020-02-29) has been added to the list.
#
#
# Zero Discrimination Day (2020-03-01) has been added to the list.
#
#
# Texas Independence Day (2020-03-02) has been added to the list.
#
#
# World Wildlife Day (2020-03-03) has been added to the list.
#
#
# Casimir Pulaski Day (2020-03-04) has been added to the list.
#
#
# Employee Appreciation Day (2020-03-06) has been added to the list.
#
#
# International Women's Day (2020-03-08) has been added to the list.
#
#
# Holi (2020-03-09) has been added to the list.
#
#
# Purim (2020-03-10) has been added to the list.
#
#
# World Kidney Day (2020-03-12) has been added to the list.
#
#
# Friday the 13th (2020-03-13) has been added to the list.
#
#
# St. Patrick's Day (2020-03-17) has been added to the list.
#
#
# First Day of Stay at Home Order (2020-03-19) has been added to the list.
#
#
# French Language Day (2020-03-20) has been added to the list.
#
#
# International Day for the Elimination of Racial Discrimination (2020-03-21) has been added to the list.
#
#
# Isra and Mi'raj (2020-03-22) has been added to the list.
#
#
# World Meteorological Day (2020-03-23) has been added to the list.
#
#
# World Tuberculosis Day (2020-03-24) has been added to the list.
#
#
# International Day of Remembrance of Slavery Victims and the Transatlantic Slave Trade (2020-03-25) has been added to the list.
#
#
# First Day of Stay at Home Order (2020-03-26) has been added to the list.
#
#
# First Day of Stay at Home Order (2020-03-27) has been added to the list.
#
#
# Earth Hour (2020-03-28) has been added to the list.
#
#
# First Day of Stay at Home Order (2020-03-29) has been added to the list.
#
#
# First Day of Stay at Home Order (2020-03-30) has been added to the list.
#
#
# First Day of Stay at Home Order (2020-03-31) has been added to the list.
#
#
# April Fool's Day (2020-04-01) has been added to the list.
#
#
# World Autism Awareness Day (2020-04-02) has been added to the list.
#
#
# First Day of Stay at Home Order (2020-04-03) has been added to the list.
#
#
# United Nations' Mine Awareness Day (2020-04-04) has been added to the list.
#
#
# Palm Sunday (2020-04-05) has been added to the list.
#
#
# International Day of Sport for Development and Peace (2020-04-06) has been added to the list.
#
#
# United Nations' World Health Day (2020-04-07) has been added to the list.
#
#
# Passover Eve (2020-04-08) has been added to the list.
#
#
# Maundy Thursday (2020-04-09) has been added to the list.
#
#
# Good Friday (2020-04-10) has been added to the list.
#
#
# Holy Saturday (2020-04-11) has been added to the list.
#
#
# International Day of Human Space Flight (2020-04-12) has been added to the list.
#
#
# Easter Monday (2020-04-13) has been added to the list.
#
#
# World Chagas Disease Day (2020-04-14) has been added to the list.
#
#
# Father Damien Day (2020-04-15) has been added to the list.
#
#
# Last Day of Passover (2020-04-16) has been added to the list.
#
#
# Orthodox Good Friday (2020-04-17) has been added to the list.
#
#
# Orthodox Holy Saturday (2020-04-18) has been added to the list.
#
#
# Orthodox Easter (2020-04-19) has been added to the list.
#
#
# Orthodox Easter Monday (2020-04-20) has been added to the list.
#
#
# Yom HaShoah (2020-04-21) has been added to the list.
#
#
# Earth Day (2020-04-22) has been added to the list.
#
#
# World Book and Copyright Day (2020-04-23) has been added to the list.
#
#
# Ramadan Starts (2020-04-24) has been added to the list.
#
#
# International Delegate's Day (2020-04-25) has been added to the list.
#
#
# World Intellectual Property Day (2020-04-26) has been added to the list.
#
#
# Arbor Day (2020-04-27) has been added to the list.
#
#
# World Day for Safety and Health at Work (2020-04-28) has been added to the list.
#
#
# Yom Ha'atzmaut (2020-04-29) has been added to the list.
#
#
# International Jazz Day (2020-04-30) has been added to the list.
#
#
# Last Day of Stay at Home Directive (2020-05-01) has been added to the list.
#
#
# World Tuna Day (2020-05-02) has been added to the list.
#
#
# World Press Freedom Day (2020-05-03) has been added to the list.
#
#
# Last Day of Stay at Home Order (2020-05-04) has been added to the list.
#
#
# World Portuguese Language Day (2020-05-05) has been added to the list.
#
#
# National Nurses Day (2020-05-06) has been added to the list.
#
#
# Day of Vesak (2020-05-07) has been added to the list.
#
#
# Time of Remembrance and Reconciliation for Those Who Lost Their Lives during the Second World War (2020-05-08) has been added to the list.
#
#
# World Migratory Bird Day (2020-05-09) has been added to the list.
#
#
# Mother's Day (2020-05-10) has been added to the list.
#
#
# Confederate Memorial Day observed (2020-05-11) has been added to the list.
#
#
# Lag BaOmer (2020-05-12) has been added to the list.
#
#
# Last Day of Stay at Home Order (2020-05-13) has been added to the list.
#
#
# International Day of Families (2020-05-15) has been added to the list.
#
#
# International Day of Living Together in Peace (2020-05-16) has been added to the list.
#
#
# World Telecommunication and Information Society Day (2020-05-17) has been added to the list.
#
#
# Last Day of Stay at Home Advisory (2020-05-18) has been added to the list.
#
#
# Lailat al-Qadr (2020-05-19) has been added to the list.
#
#
# World Bee Day (2020-05-20) has been added to the list.
#
#
# Ascension Day (2020-05-21) has been added to the list.
#
#
# International Day for Biological Diversity (2020-05-22) has been added to the list.
#
#
# International Day to End Obstetric Fistula (2020-05-23) has been added to the list.
#
#
# Eid al-Fitr (2020-05-24) has been added to the list.
#
#
# African Liberation Day (2020-05-25) has been added to the list.
#
#
# Shavuot (2020-05-29) has been added to the list.
#
#
# Last Day of Stay at Home Order (2020-05-30) has been added to the list.
#
#
# Pentecost (2020-05-31) has been added to the list.
#
#
# Whit Monday (2020-06-01) has been added to the list.
#
#
# World Bicycle Day (2020-06-03) has been added to the list.
#
#
# International Day of Innocent Children Victims of Aggression (2020-06-04) has been added to the list.
#
#
# World Environment Day (2020-06-05) has been added to the list.
#
#
# Day of the Russian Language (2020-06-06) has been added to the list.
#
#
# Trinity Sunday (2020-06-07) has been added to the list.
#
#
# World Oceans Day (2020-06-08) has been added to the list.
#
#
# Primary Election Day (2020-06-09) has been added to the list.
#
#
# Last Day of Stay at Home Order (2020-06-10) has been added to the list.
#
#
# Corpus Christi (2020-06-11) has been added to the list.
#
#
# World Day Against Child Labour (2020-06-12) has been added to the list.
#
#
# International Albinism Awareness Day (2020-06-13) has been added to the list.
#
#
# World Blood Donor Day (2020-06-14) has been added to the list.
#
#
# World Elder Abuse Awareness Day (2020-06-15) has been added to the list.
#
#
# International Day of Family Remittances (2020-06-16) has been added to the list.
#
#
# World Day to Combat Desertification and Drought (2020-06-17) has been added to the list.
#
#
# Sustainable Gastronomy Day (2020-06-18) has been added to the list.
#
#
# International Day for the Elimination of Sexual Violence in Conflict (2020-06-19) has been added to the list.
#
#
# World Refugee Day (2020-06-20) has been added to the list.
#
#
# International Day of Yoga (2020-06-21) has been added to the list.
#
#
# Public Service Day (2020-06-23) has been added to the list.
#
#
# Day of the Seafarer (2020-06-25) has been added to the list.
#
#
# International Day Against Drug Abuse and Illicit Trafficking (2020-06-26) has been added to the list.
#
#
# Micro-, Small and Medium-sized Enterprises Day (2020-06-27) has been added to the list.
#
#
# Carolina Day (2020-06-28) has been added to the list.
#
#
# International Day of the Tropics (2020-06-29) has been added to the list.
#
#
# International Asteroid Day (2020-06-30) has been added to the list.
#
#
# Independence Day (substitute) (2020-07-03) has been added to the list.
#
#
# International Day of Cooperatives (2020-07-04) has been added to the list.
#
#
# World Population Day (2020-07-11) has been added to the list.
#
#
# Nathan Bedford Forrest Day (2020-07-13) has been added to the list.
#
#
# Bastille Day (2020-07-14) has been added to the list.
#
#
# World Youth Skills Day (2020-07-15) has been added to the list.
#
#
# Rural Transit Day (2020-07-16) has been added to the list.
#
#
# Nelson Mandela Day (2020-07-18) has been added to the list.
#
#
# World Chess Day (2020-07-20) has been added to the list.
#
#
# Pioneer Day (2020-07-24) has been added to the list.
#
#
# Parents' Day (2020-07-26) has been added to the list.
#
#
# Korean War Veteran Recognition Day (2020-07-27) has been added to the list.
#
#
# World Hepatitis Day (2020-07-28) has been added to the list.
#
#
# Tisha B'Av (2020-07-30) has been added to the list.
#
#
# Eid al-Adha (2020-07-31) has been added to the list.
#
#
# Colorado Day (2020-08-01) has been added to the list.
#
#
# American Family Day (2020-08-02) has been added to the list.
#
#
# Raksha Bandhan (2020-08-03) has been added to the list.
#
#
# Coast Guard Birthday (2020-08-04) has been added to the list.
#
#
# Purple Heart Day (2020-08-07) has been added to the list.
#
#
# International Day of the World's Indigenous People (2020-08-09) has been added to the list.
#
#
# Janmashtami (2020-08-10) has been added to the list.
#
#
# International Youth Day (2020-08-12) has been added to the list.
#
#
# Assumption of Mary (2020-08-15) has been added to the list.
#
#
# National Navajo Code Talkers Day (2020-08-16) has been added to the list.
#
#
# Bennington Battle Day observed (2020-08-17) has been added to the list.
#
#
# World Humanitarian Day (2020-08-19) has been added to the list.
#
#
# Muharram (2020-08-20) has been added to the list.
#
#
# Ganesh Chaturthi (2020-08-21) has been added to the list.
#
#
# International Day Commemorating the Victims of Acts of Violence Based on Religion or Belief (2020-08-22) has been added to the list.
#
#
# International Day for the Remembrance of the Slave Trade and its Abolition (2020-08-23) has been added to the list.
#
#
# Susan B. Anthony Day (2020-08-26) has been added to the list.
#
#
# Lyndon Baines Johnson Day (2020-08-27) has been added to the list.
#
#
# Last Day of Stay at Home Instructions (2020-08-28) has been added to the list.
#
#
# Ashura (2020-08-29) has been added to the list.
#
#
# International Day of the Victims of Enforced Disappearances (2020-08-30) has been added to the list.
#
#
# International Overdose Awareness Day (2020-08-31) has been added to the list.
#
#
# World Sexual Health Day (2020-09-04) has been added to the list.
#
#
# International Day of Charity (2020-09-05) has been added to the list.
#
#
# International Day of Clean Air for Blue Skies (2020-09-07) has been added to the list.
#
#
# International Literacy Day (2020-09-08) has been added to the list.
#
#
# International Day to Protect Education from Attack (2020-09-09) has been added to the list.
#
#
# World Suicide Prevention Day (2020-09-10) has been added to the list.
#
#
# First Responders Day (2020-09-11) has been added to the list.
#
#
# International Day for South-South Cooperation (2020-09-12) has been added to the list.
#
#
# National Grandparents Day (2020-09-13) has been added to the list.
#
#
# International Day of Democracy (2020-09-15) has been added to the list.
#
#
# International Day for the Preservation of the Ozone Layer (2020-09-16) has been added to the list.
#
#
# World Patient Safety Day (2020-09-17) has been added to the list.
#
#
# International Equal Pay Day (2020-09-18) has been added to the list.
#
#
# Rosh Hashana (2020-09-19) has been added to the list.
#
#
# International Day of Peace (2020-09-21) has been added to the list.
#
#
# Emancipation Day (2020-09-22) has been added to the list.
#
#
# International Day of Sign Languages (2020-09-23) has been added to the list.
#
#
# World Maritime Day (2020-09-24) has been added to the list.
#
#
# Native American Day (2020-09-25) has been added to the list.
#
#
# International Day for the Total Elimination of Nuclear Weapons (2020-09-26) has been added to the list.
#
#
# World Tourism Day (2020-09-27) has been added to the list.
#
#
# Yom Kippur (2020-09-28) has been added to the list.
#
#
# International Day of Awareness of Food Loss and Waste (2020-09-29) has been added to the list.
#
#
# International Translation Day (2020-09-30) has been added to the list.
#
#
# International Day of Older Persons (2020-10-01) has been added to the list.
#
#
# International Day of Non-Violence (2020-10-02) has been added to the list.
#
#
# First Day of Sukkot (2020-10-03) has been added to the list.
#
#
# Feast of St Francis of Assisi (2020-10-04) has been added to the list.
#
#
# World Teachers' Day (2020-10-05) has been added to the list.
#
#
# World Cerebral Palsy Day (2020-10-06) has been added to the list.
#
#
# World Sight Day (2020-10-08) has been added to the list.
#
#
# Last Day of Sukkot (2020-10-09) has been added to the list.
#
#
# Shmini Atzeret (2020-10-10) has been added to the list.
#
#
# Simchat Torah (2020-10-11) has been added to the list.
#
#
# World Spanish Language Day (2020-10-12) has been added to the list.
#
#
# Navy Birthday (2020-10-13) has been added to the list.
#
#
# International Day for Natural Disaster Reduction (2020-10-14) has been added to the list.
#
#
# International Day of Rural Women (2020-10-15) has been added to the list.
#
#
# World Food Day (2020-10-16) has been added to the list.
#
#
# Navratri (2020-10-17) has been added to the list.
#
#
# Alaska Day (2020-10-18) has been added to the list.
#
#
# Alaska Day observed (2020-10-19) has been added to the list.
#
#
# World Statistics Day (2020-10-20) has been added to the list.
#
#
# United Nations Day (2020-10-24) has been added to the list.
#
#
# Dussehra (2020-10-25) has been added to the list.
#
#
# World Day for Audiovisual Heritage (2020-10-27) has been added to the list.
#
#
# The Prophet's Birthday (2020-10-29) has been added to the list.
#
#
# Nevada Day (2020-10-30) has been added to the list.
#
#
# World Cities Day (2020-10-31) has been added to the list.
#
#
# All Saints' Day (2020-11-01) has been added to the list.
#
#
# All Souls' Day (2020-11-02) has been added to the list.
#
#
# Election Day (General Election) (2020-11-03) has been added to the list.
#
#
# World Tsunami Awareness Day (2020-11-05) has been added to the list.
#
#
# International Day for Preventing the Exploitation of the Environment in War and Armed Conflict (2020-11-06) has been added to the list.
#
#
# Barack Obama Day (2020-11-09) has been added to the list.
#
#
# World Science Day for Peace and Development (2020-11-10) has been added to the list.
#
#
# Veterans Day (2020-11-11) has been added to the list.
#
#
# World Pneumonia Day (2020-11-12) has been added to the list.
#
#
# Friday the 13th (2020-11-13) has been added to the list.
#
#
# Diwali/Deepavali (2020-11-14) has been added to the list.
#
#
# World Day of Remembrance for Road Traffic Victims (2020-11-15) has been added to the list.
#
#
# International Day for Tolerance (2020-11-16) has been added to the list.
#
#
# World Prematurity Day (2020-11-17) has been added to the list.
#
#
# World Philosophy Day (2020-11-19) has been added to the list.
#
#
# Universal Children's Day (2020-11-20) has been added to the list.
#
#
# World Television Day (2020-11-21) has been added to the list.
#
#
# International Day for the Elimination of Violence against Women (2020-11-25) has been added to the list.
#
#
# Thanksgiving Day (2020-11-26) has been added to the list.
#
#
# State Holiday (2020-11-27) has been added to the list.
#
#
# First Sunday of Advent (2020-11-29) has been added to the list.
#
#
# Day of Remembrance for all Victims of Chemical Warfare (2020-11-30) has been added to the list.
#
#
# World AIDS Day (2020-12-01) has been added to the list.
#
#
# International Day for the Abolition of Slavery (2020-12-02) has been added to the list.
#
#
# International Day of Persons with Disabilities (2020-12-03) has been added to the list.
#
#
# International Day of Banks (2020-12-04) has been added to the list.
#
#
# International Volunteer Day for Economic and Social Development (2020-12-05) has been added to the list.
#
#
# St Nicholas Day (2020-12-06) has been added to the list.
#
#
# International Civil Aviation Day (2020-12-07) has been added to the list.
#
#
# Feast of the Immaculate Conception (2020-12-08) has been added to the list.
#
#
# International Anti-Corruption Day (2020-12-09) has been added to the list.
#
#
# Human Rights Day (2020-12-10) has been added to the list.
#
#
# Chanukah/Hanukkah (first day) (2020-12-11) has been added to the list.
#
#
# International Day of Neutrality (2020-12-12) has been added to the list.
#
#
# National Guard Birthday (2020-12-13) has been added to the list.
#
#
# Bill of Rights Day (2020-12-15) has been added to the list.
#
#
# Pan American Aviation Day (2020-12-17) has been added to the list.
#
#
# Last Day of Chanukah (2020-12-18) has been added to the list.
#
#
# International Human Solidarity Day (2020-12-20) has been added to the list.
#
#
# December Solstice (2020-12-21) has been added to the list.
#
#
# Christmas Eve (2020-12-24) has been added to the list.
#
#
# Asarah B'Tevet (2020-12-25) has been added to the list.
#
#
# Kwanzaa (first day) (2020-12-26) has been added to the list.
#
#
# International Day of Epidemic Preparedness (2020-12-27) has been added to the list.
#
#
# New Year's Eve (2020-12-31) has been added to the list.
#
#
# New Year's Day (2021-01-01) has been added to the list.
#
#
# World Braille Day (2021-01-04) has been added to the list.
#
#
# Epiphany (2021-01-06) has been added to the list.
#
#
# Orthodox Christmas Day (2021-01-07) has been added to the list.
#
#
# Battle of New Orleans (2021-01-08) has been added to the list.
#
#
# Stephen Foster Memorial Day (2021-01-13) has been added to the list.
#
#
# Orthodox New Year (2021-01-14) has been added to the list.
#
#
# World Religion Day (2021-01-17) has been added to the list.
#
#
# Martin Luther King Jr. Day (2021-01-18) has been added to the list.
#
#
# Robert E. Lee's Birthday (2021-01-19) has been added to the list.
#
#
# Inauguration Day (2021-01-20) has been added to the list.
#
#
# International Day of Education (2021-01-24) has been added to the list.
#
#
# International Customs Day (2021-01-26) has been added to the list.
#
#
# International Day of Commemoration in Memory of the Victims of the Holocaust (2021-01-27) has been added to the list.
#
#
# Tu Bishvat/Tu B'Shevat (2021-01-28) has been added to the list.
#
#
# Kansas Day (2021-01-29) has been added to the list.
#
#
# World Leprosy Day (2021-01-31) has been added to the list.
#
#
# National Freedom Day (2021-02-01) has been added to the list.
#
#
# World Wetlands Day (2021-02-02) has been added to the list.
#
#
# National Girls and Women in Sports Day (2021-02-03) has been added to the list.
#
#
# International Day of Human Fraternity (2021-02-04) has been added to the list.
#
#
# National Wear Red Day (2021-02-05) has been added to the list.
#
#
# International Day of Zero Tolerance for Female Genital Mutilation (2021-02-06) has been added to the list.
#
#
# Super Bowl (2021-02-07) has been added to the list.
#
#
# World Pulses Day (2021-02-10) has been added to the list.
#
#
# International Day of Women and Girls in Science (2021-02-11) has been added to the list.
#
#
# Lincoln's Birthday (2021-02-12) has been added to the list.
#
#
# World Radio Day (2021-02-13) has been added to the list.
#
#
# Valentine's Day (2021-02-14) has been added to the list.
#
#
# Presidents' Day (2021-02-15) has been added to the list.
#
#
# Shrove Tuesday/Mardi Gras (2021-02-16) has been added to the list.
#
#
# Ash Wednesday (2021-02-17) has been added to the list.
#
#
# World Day of Social Justice (2021-02-20) has been added to the list.
#
#
# International Mother Language Day (2021-02-21) has been added to the list.
#
#
# African-American Scientist and Inventor Day (2021-02-25) has been added to the list.
#
#
# Purim (2021-02-26) has been added to the list.
#
#
# Linus Pauling Day (2021-02-28) has been added to the list.
#
#
# Zero Discrimination Day (2021-03-01) has been added to the list.
#
#
# Texas Independence Day (2021-03-02) has been added to the list.
#
#
# World Wildlife Day (2021-03-03) has been added to the list.
#
#
# Casimir Pulaski Day (2021-03-04) has been added to the list.
#
#
# Employee Appreciation Day (2021-03-05) has been added to the list.
#
#
# International Women's Day (2021-03-08) has been added to the list.
#
#
# Maha Shivaratri (2021-03-11) has been added to the list.
#
#
# Daylight Saving Time starts (2021-03-14) has been added to the list.
#
#
# St. Patrick's Day (2021-03-17) has been added to the list.
#
#
# French Language Day (2021-03-20) has been added to the list.
#
#
# International Day for the Elimination of Racial Discrimination (2021-03-21) has been added to the list.
#
#
# World Water Day (2021-03-22) has been added to the list.
#
#
# World Meteorological Day (2021-03-23) has been added to the list.
#
#
# World Tuberculosis Day (2021-03-24) has been added to the list.
#
#
# International Day of Remembrance of Slavery Victims and the Transatlantic Slave Trade (2021-03-25) has been added to the list.
#
#
# Prince Jonah Kuhio Kalanianaole Day (2021-03-26) has been added to the list.
#
#
# Passover Eve (2021-03-27) has been added to the list.
#
#
# Palm Sunday (2021-03-28) has been added to the list.
#
#
# Seward's Day (2021-03-29) has been added to the list.
#
#
# Wyoming Veterans Welcome Home Day (2021-03-30) has been added to the list.
#
#
# César Chávez Day (2021-03-31) has been added to the list.
#
#
# Maundy Thursday (2021-04-01) has been added to the list.
#
#
# World Autism Awareness Day (2021-04-02) has been added to the list.
#
#
# Holy Saturday (2021-04-03) has been added to the list.
#
#
# Last Day of Passover (2021-04-04) has been added to the list.
#
#
# International Day of Conscience (2021-04-05) has been added to the list.
#
#
# International Day of Sport for Development and Peace (2021-04-06) has been added to the list.
#
#
# United Nations' World Health Day (2021-04-07) has been added to the list.
#
#
# Yom HaShoah (2021-04-08) has been added to the list.
#
#
# International Day of Human Space Flight (2021-04-12) has been added to the list.
#
#
# Ramadan Starts (2021-04-13) has been added to the list.
#
#
# World Chagas Disease Day (2021-04-14) has been added to the list.
#
#
# Yom Ha'atzmaut (2021-04-15) has been added to the list.
#
#
# Emancipation Day (2021-04-16) has been added to the list.
#
#
# International Day for Monuments and Sites (2021-04-18) has been added to the list.
#
#
# Patriots' Day (2021-04-19) has been added to the list.
#
#
# Chinese Language Day (2021-04-20) has been added to the list.
#
#
# World Creativity and Innovation Day (2021-04-21) has been added to the list.
#
#
# International Girls in ICT Day (2021-04-22) has been added to the list.
#
#
# World Book and Copyright Day (2021-04-23) has been added to the list.
#
#
# International Day of Multilateralism and Diplomacy for Peace (2021-04-24) has been added to the list.
#
#
# International Delegate's Day (2021-04-25) has been added to the list.
#
#
# World Intellectual Property Day (2021-04-26) has been added to the list.
#
#
# World Day for Safety and Health at Work (2021-04-28) has been added to the list.
#
#
# Lag BaOmer (2021-04-30) has been added to the list.
#
#
# Orthodox Holy Saturday (2021-05-01) has been added to the list.
#
#
# Orthodox Easter (2021-05-02) has been added to the list.
#
#
# Orthodox Easter Monday (2021-05-03) has been added to the list.
#
#
# Kent State Shootings Remembrance (2021-05-04) has been added to the list.
#
#
# World Portuguese Language Day (2021-05-05) has been added to the list.
#
#
# National Nurses Day (2021-05-06) has been added to the list.
#
#
# Truman Day observed (2021-05-07) has been added to the list.
#
#
# Lailat al-Qadr (2021-05-08) has been added to the list.
#
#
# Mother's Day (2021-05-09) has been added to the list.
#
#
# International Day of Argania (2021-05-10) has been added to the list.
#
#
# International Nurses Day (2021-05-12) has been added to the list.
#
#
# Ascension Day (2021-05-13) has been added to the list.
#
#
# Native American Day (2021-05-14) has been added to the list.
#
#
# International Day of Families (2021-05-15) has been added to the list.
#
#
# International Day of Living Together in Peace (2021-05-16) has been added to the list.
#
#
# Shavuot (2021-05-17) has been added to the list.
#
#
# Emergency Medical Services for Children Day (2021-05-19) has been added to the list.
#
#
# World Bee Day (2021-05-20) has been added to the list.
#
#
# World Day for Cultural Diversity for Dialogue and Development (2021-05-21) has been added to the list.
#
#
# International Day for Biological Diversity (2021-05-22) has been added to the list.
#
#
# Pentecost (2021-05-23) has been added to the list.
#
#
# Whit Monday (2021-05-24) has been added to the list.
#
#
# African Liberation Day (2021-05-25) has been added to the list.
#
#
# Day of Vesak (2021-05-26) has been added to the list.
#
#
# International Day of United Nations Peacekeepers (2021-05-29) has been added to the list.
#
#
# Trinity Sunday (2021-05-30) has been added to the list.
#
#
# World No Tobacco Day (2021-05-31) has been added to the list.
#
#
# Global Day of Parents (2021-06-01) has been added to the list.
#
#
# Corpus Christi (2021-06-03) has been added to the list.
#
#
# International Day of Innocent Children Victims of Aggression (2021-06-04) has been added to the list.
#
#
# World Environment Day (2021-06-05) has been added to the list.
#
#
# Day of the Russian Language (2021-06-06) has been added to the list.
#
#
# World Food Safety Day (2021-06-07) has been added to the list.
#
#
# World Oceans Day (2021-06-08) has been added to the list.
#
#
# Kamehameha Day (2021-06-11) has been added to the list.
#
#
# World Day Against Child Labour (2021-06-12) has been added to the list.
#
#
# International Albinism Awareness Day (2021-06-13) has been added to the list.
#
#
# World Blood Donor Day (2021-06-14) has been added to the list.
#
#
# World Elder Abuse Awareness Day (2021-06-15) has been added to the list.
#
#
# International Day of Family Remittances (2021-06-16) has been added to the list.
#
#
# World Day to Combat Desertification and Drought (2021-06-17) has been added to the list.
#
#
# Sustainable Gastronomy Day (2021-06-18) has been added to the list.
#
#
# International Day for the Elimination of Sexual Violence in Conflict (2021-06-19) has been added to the list.
#
#
# World Refugee Day (2021-06-20) has been added to the list.
#
#
# International Day of Yoga (2021-06-21) has been added to the list.
#
#
# Public Service Day (2021-06-23) has been added to the list.
#
#
# Day of the Seafarer (2021-06-25) has been added to the list.
#
#
# International Day Against Drug Abuse and Illicit Trafficking (2021-06-26) has been added to the list.
#
#
# Micro-, Small and Medium-sized Enterprises Day (2021-06-27) has been added to the list.
#
#
# Carolina Day (2021-06-28) has been added to the list.
#
#
# International Day of the Tropics (2021-06-29) has been added to the list.
#
#
# International Asteroid Day (2021-06-30) has been added to the list.
#
#
# International Day of Cooperatives (2021-07-03) has been added to the list.
#
#
# Independence Day (2021-07-04) has been added to the list.
#
#
# Independence Day (substitute) (2021-07-05) has been added to the list.
#
#
# World Population Day (2021-07-11) has been added to the list.
#
#
# Nathan Bedford Forrest Day (2021-07-13) has been added to the list.
#
#
# Bastille Day (2021-07-14) has been added to the list.
#
#
# World Youth Skills Day (2021-07-15) has been added to the list.
#
#
# Rural Transit Day (2021-07-16) has been added to the list.
#
#
# Tisha B'Av (2021-07-18) has been added to the list.
#
#
# Eid al-Adha (2021-07-20) has been added to the list.
#
#
# Pioneer Day observed (2021-07-23) has been added to the list.
#
#
# Pioneer Day (2021-07-24) has been added to the list.
#
#
# World Drowning Prevention Day (2021-07-25) has been added to the list.
#
#
# Korean War Veteran Recognition Day (2021-07-27) has been added to the list.
#
#
# World Hepatitis Day (2021-07-28) has been added to the list.
#
#
# International Day of Friendship (2021-07-30) has been added to the list.
#
#
# Colorado Day (2021-08-01) has been added to the list.
#
#
# Coast Guard Birthday (2021-08-04) has been added to the list.
#
#
# Purple Heart Day (2021-08-07) has been added to the list.
#
#
# International Day of the World's Indigenous People (2021-08-09) has been added to the list.
#
#
# Muharram (2021-08-10) has been added to the list.
#
#
# International Youth Day (2021-08-12) has been added to the list.
#
#
# Friday the 13th (2021-08-13) has been added to the list.
#
#
# Assumption of Mary (2021-08-15) has been added to the list.
#
#
# Bennington Battle Day (2021-08-16) has been added to the list.
#
#
# Ashura (2021-08-19) has been added to the list.
#
#
# Hawaii Statehood Day (2021-08-20) has been added to the list.
#
#
# Raksha Bandhan (2021-08-21) has been added to the list.
#
#
# International Day Commemorating the Victims of Acts of Violence Based on Religion or Belief (2021-08-22) has been added to the list.
#
#
# International Day for the Remembrance of the Slave Trade and its Abolition (2021-08-23) has been added to the list.
#
#
# Susan B. Anthony Day (2021-08-26) has been added to the list.
#
#
# Lyndon Baines Johnson Day (2021-08-27) has been added to the list.
#
#
# International Day against Nuclear Tests (2021-08-29) has been added to the list.
#
#
# International Day of the Victims of Enforced Disappearances (2021-08-30) has been added to the list.
#
#
# International Day for People of African Descent (2021-08-31) has been added to the list.
#
#
# World Sexual Health Day (2021-09-04) has been added to the list.
#
#
# International Day of Charity (2021-09-05) has been added to the list.
#
#
# Labor Day (2021-09-06) has been added to the list.
#
#
# Rosh Hashana (2021-09-07) has been added to the list.
#
#
# International Literacy Day (2021-09-08) has been added to the list.
#
#
# International Day to Protect Education from Attack (2021-09-09) has been added to the list.
#
#
# Ganesh Chaturthi (2021-09-10) has been added to the list.
#
#
# First Responders Day (2021-09-11) has been added to the list.
#
#
# International Day for South-South Cooperation (2021-09-12) has been added to the list.
#
#
# International Programmers' Day (2021-09-13) has been added to the list.
#
#
# International Day of Democracy (2021-09-15) has been added to the list.
#
#
# Yom Kippur (2021-09-16) has been added to the list.
#
#
# World Patient Safety Day (2021-09-17) has been added to the list.
#
#
# International Equal Pay Day (2021-09-18) has been added to the list.
#
#
# First Day of Sukkot (2021-09-21) has been added to the list.
#
#
# Emancipation Day (2021-09-22) has been added to the list.
#
#
# International Day of Sign Languages (2021-09-23) has been added to the list.
#
#
# Native American Day (2021-09-24) has been added to the list.
#
#
# Public Lands Day (2021-09-25) has been added to the list.
#
#
# International Day for the Total Elimination of Nuclear Weapons (2021-09-26) has been added to the list.
#
#
# Last Day of Sukkot (2021-09-27) has been added to the list.
#
#
# Shmini Atzeret (2021-09-28) has been added to the list.
#
#
# Simchat Torah (2021-09-29) has been added to the list.
#
#
# World Maritime Day (2021-09-30) has been added to the list.
#
#
# International Day of Older Persons (2021-10-01) has been added to the list.
#
#
# International Day of Non-Violence (2021-10-02) has been added to the list.
#
#
# Feast of St Francis of Assisi (2021-10-04) has been added to the list.
#
#
# World Teachers' Day (2021-10-05) has been added to the list.
#
#
# Navratri (2021-10-06) has been added to the list.
#
#
# World Post Day (2021-10-09) has been added to the list.
#
#
# World Mental Health Day (2021-10-10) has been added to the list.
#
#
# International Day of the Girl Child (2021-10-11) has been added to the list.
#
#
# World Spanish Language Day (2021-10-12) has been added to the list.
#
#
# International Day for Natural Disaster Reduction (2021-10-13) has been added to the list.
#
#
# Dussehra (2021-10-14) has been added to the list.
#
#
# International Day of Rural Women (2021-10-15) has been added to the list.
#
#
# World Food Day (2021-10-16) has been added to the list.
#
#
# International Day for the Eradication of Poverty (2021-10-17) has been added to the list.
#
#
# Alaska Day (2021-10-18) has been added to the list.
#
#
# The Prophet's Birthday (2021-10-19) has been added to the list.
#
#
# United Nations Day (2021-10-24) has been added to the list.
#
#
# World Day for Audiovisual Heritage (2021-10-27) has been added to the list.
#
#
# World Stroke Day (2021-10-29) has been added to the list.
#
#
# World Cities Day (2021-10-31) has been added to the list.
#
#
# All Saints' Day (2021-11-01) has been added to the list.
#
#
# All Souls' Day (2021-11-02) has been added to the list.
#
#
# Diwali/Deepavali (2021-11-03) has been added to the list.
#
#
# Diwali/Deepavali (2021-11-04) has been added to the list.
#
#
# World Tsunami Awareness Day (2021-11-05) has been added to the list.
#
#
# International Day for Preventing the Exploitation of the Environment in War and Armed Conflict (2021-11-06) has been added to the list.
#
#
# New York City Marathon (2021-11-07) has been added to the list.
#
#
# Barack Obama Day (2021-11-08) has been added to the list.
#
#
# World Science Day for Peace and Development (2021-11-10) has been added to the list.
#
#
# Veterans Day (2021-11-11) has been added to the list.
#
#
# World Pneumonia Day (2021-11-12) has been added to the list.
#
#
# World Diabetes Day (2021-11-14) has been added to the list.
#
#
# International Day for Tolerance (2021-11-16) has been added to the list.
#
#
# World Prematurity Day (2021-11-17) has been added to the list.
#
#
# World Philosophy Day (2021-11-18) has been added to the list.
#
#
# World Toilet Day (2021-11-19) has been added to the list.
#
#
# Universal Children's Day (2021-11-20) has been added to the list.
#
#
# World Day of Remembrance for Road Traffic Victims (2021-11-21) has been added to the list.
#
#
# International Day for the Elimination of Violence against Women (2021-11-25) has been added to the list.
#
#
# State Holiday (2021-11-26) has been added to the list.
#
#
# First Sunday of Advent (2021-11-28) has been added to the list.
#
#
# Chanukah/Hanukkah (first day) (2021-11-29) has been added to the list.
#
#
# Day of Remembrance for all Victims of Chemical Warfare (2021-11-30) has been added to the list.
#
#
# World AIDS Day (2021-12-01) has been added to the list.
#
#
# International Day for the Abolition of Slavery (2021-12-02) has been added to the list.
#
#
# International Day of Persons with Disabilities (2021-12-03) has been added to the list.
#
#
# International Day of Banks (2021-12-04) has been added to the list.
#
#
# International Volunteer Day for Economic and Social Development (2021-12-05) has been added to the list.
#
#
# Last Day of Chanukah (2021-12-06) has been added to the list.
#
#
# International Civil Aviation Day (2021-12-07) has been added to the list.
#
#
# Feast of the Immaculate Conception (2021-12-08) has been added to the list.
#
#
# International Anti-Corruption Day (2021-12-09) has been added to the list.
#
#
# Human Rights Day (2021-12-10) has been added to the list.
#
#
# International Mountain Day (2021-12-11) has been added to the list.
#
#
# International Day of Neutrality (2021-12-12) has been added to the list.
#
#
# National Guard Birthday (2021-12-13) has been added to the list.
#
#
# Asarah B'Tevet (2021-12-14) has been added to the list.
#
#
# Bill of Rights Day (2021-12-15) has been added to the list.
#
#
# Pan American Aviation Day (2021-12-17) has been added to the list.
#
#
# International Migrants Day (2021-12-18) has been added to the list.
#
#
# International Human Solidarity Day (2021-12-20) has been added to the list.
#
#
# December Solstice (2021-12-21) has been added to the list.
#
#
# Washington's Birthday (2021-12-23) has been added to the list.
#
#
# Christmas Day (substitute) (2021-12-24) has been added to the list.
#
#
# Christmas Day (2021-12-25) has been added to the list.
#
#
# Kwanzaa (first day) (2021-12-26) has been added to the list.
#
#
# International Day of Epidemic Preparedness (2021-12-27) has been added to the list.
#
#
# New Year Holiday (2021-12-30) has been added to the list.
#
#
# New Year's Day (substitute) (2021-12-31) has been added to the list.
#
#
# New Year's Day (2022-01-01) has been added to the list.
#
#
# New Year's Day (substitute) (2022-01-03) has been added to the list.
#
#
# World Braille Day (2022-01-04) has been added to the list.
#
#
# Epiphany (2022-01-06) has been added to the list.
#
#
# Orthodox Christmas Day (2022-01-07) has been added to the list.
#
#
# Battle of New Orleans (2022-01-08) has been added to the list.
#
#
# Stephen Foster Memorial Day (2022-01-13) has been added to the list.
#
#
# Orthodox New Year (2022-01-14) has been added to the list.
#
#
# World Religion Day (2022-01-16) has been added to the list.
#
#
# Tu Bishvat/Tu B'Shevat (2022-01-17) has been added to the list.
#
#
# Robert E. Lee's Birthday (2022-01-19) has been added to the list.
#
#
# International Day of Education (2022-01-24) has been added to the list.
#
#
# International Customs Day (2022-01-26) has been added to the list.
#
#
# International Day of Commemoration in Memory of the Victims of the Holocaust (2022-01-27) has been added to the list.
#
#
# Kansas Day (2022-01-29) has been added to the list.
#
#
# World Leprosy Day (2022-01-30) has been added to the list.
#
#
# National Freedom Day (2022-02-01) has been added to the list.
#
#
# World Wetlands Day (2022-02-02) has been added to the list.
#
#
# International Day of Human Fraternity (2022-02-04) has been added to the list.
#
#
# International Day of Zero Tolerance for Female Genital Mutilation (2022-02-06) has been added to the list.
#
#
# World Pulses Day (2022-02-10) has been added to the list.
#
#
# International Day of Women and Girls in Science (2022-02-11) has been added to the list.
#
#
# Lincoln's Birthday (2022-02-12) has been added to the list.
#
#
# World Radio Day (2022-02-13) has been added to the list.
#
#
# Valentine's Day (2022-02-14) has been added to the list.
#
#
# Susan B. Anthony's Birthday (2022-02-15) has been added to the list.
#
#
# Elizabeth Peratrovich Day (2022-02-16) has been added to the list.
#
#
# World Day of Social Justice (2022-02-20) has been added to the list.
#
#
# International Mother Language Day (2022-02-21) has been added to the list.
#
#
# African-American Scientist and Inventor Day (2022-02-25) has been added to the list.
#
#
# Maha Shivaratri (2022-02-28) has been added to the list.
#
#
# Isra and Mi'raj (2022-03-01) has been added to the list.
#
#
# Ash Wednesday (2022-03-02) has been added to the list.
#
#
# World Wildlife Day (2022-03-03) has been added to the list.
#
#
# Casimir Pulaski Day (2022-03-04) has been added to the list.
#
#
# Casimir Pulaski Day (2022-03-07) has been added to the list.
#
#
# International Women's Day (2022-03-08) has been added to the list.
#
#
# International Day of Women Judges (2022-03-10) has been added to the list.
#
#
# Daylight Saving Time starts (2022-03-13) has been added to the list.
#
#
# Purim (2022-03-17) has been added to the list.
#
#
# Holi (2022-03-18) has been added to the list.
#
#
# French Language Day (2022-03-20) has been added to the list.
#
#
# International Day for the Elimination of Racial Discrimination (2022-03-21) has been added to the list.
#
#
# World Water Day (2022-03-22) has been added to the list.
#
#
# World Meteorological Day (2022-03-23) has been added to the list.
#
#
# World Tuberculosis Day (2022-03-24) has been added to the list.
#
#
# International Day of Remembrance of Slavery Victims and the Transatlantic Slave Trade (2022-03-25) has been added to the list.
#
#
# Earth Hour (2022-03-26) has been added to the list.
#
#
# Seward's Day (2022-03-28) has been added to the list.
#
#
# National Vietnam War Veterans Day (2022-03-29) has been added to the list.
#
#
# Wyoming Veterans Welcome Home Day (2022-03-30) has been added to the list.
#
#
# César Chávez Day (2022-03-31) has been added to the list.
#
#
# April Fool's Day (2022-04-01) has been added to the list.
#
#
# World Autism Awareness Day (2022-04-02) has been added to the list.
#
#
# Ramadan Starts (2022-04-03) has been added to the list.
#
#
# United Nations' Mine Awareness Day (2022-04-04) has been added to the list.
#
#
# International Day of Conscience (2022-04-05) has been added to the list.
#
#
# International Day of Sport for Development and Peace (2022-04-06) has been added to the list.
#
#
# United Nations' World Health Day (2022-04-07) has been added to the list.
#
#
# Palm Sunday (2022-04-10) has been added to the list.
#
#
# International Day of Human Space Flight (2022-04-12) has been added to the list.
#
#
# Thomas Jefferson's Birthday (2022-04-13) has been added to the list.
#
#
# Maundy Thursday (2022-04-14) has been added to the list.
#
#
# Passover Eve (2022-04-15) has been added to the list.
#
#
# Holy Saturday (2022-04-16) has been added to the list.
#
#
# Easter Sunday (2022-04-17) has been added to the list.
#
#
# International Day for Monuments and Sites (2022-04-18) has been added to the list.
#
#
# Chinese Language Day (2022-04-20) has been added to the list.
#
#
# World Creativity and Innovation Day (2022-04-21) has been added to the list.
#
#
# Orthodox Good Friday (2022-04-22) has been added to the list.
#
#
# Last Day of Passover (2022-04-23) has been added to the list.
#
#
# Orthodox Easter (2022-04-24) has been added to the list.
#
#
# Orthodox Easter Monday (2022-04-25) has been added to the list.
#
#
# World Intellectual Property Day (2022-04-26) has been added to the list.
#
#
# Administrative Professionals Day (2022-04-27) has been added to the list.
#
#
# Yom HaShoah (2022-04-28) has been added to the list.
#
#
# Arbor Day (2022-04-29) has been added to the list.
#
#
# International Jazz Day (2022-04-30) has been added to the list.
#
#
# International Family Equality Day (2022-05-01) has been added to the list.
#
#
# Eid al-Fitr (2022-05-02) has been added to the list.
#
#
# World Press Freedom Day (2022-05-03) has been added to the list.
#
#
# Kent State Shootings Remembrance (2022-05-04) has been added to the list.
#
#
# Yom Ha'atzmaut (2022-05-05) has been added to the list.
#
#
# Kentucky Oaks (2022-05-06) has been added to the list.
#
#
# Kentucky Derby (2022-05-07) has been added to the list.
#
#
# Time of Remembrance and Reconciliation for Those Who Lost Their Lives during the Second World War (2022-05-08) has been added to the list.
#
#
# Truman Day observed (2022-05-09) has been added to the list.
#
#
# International Day of Argania (2022-05-10) has been added to the list.
#
#
# International Nurses Day (2022-05-12) has been added to the list.
#
#
# Friday the 13th (2022-05-13) has been added to the list.
#
#
# World Migratory Bird Day (2022-05-14) has been added to the list.
#
#
# International Day of Families (2022-05-15) has been added to the list.
#
#
# Day of Vesak (2022-05-16) has been added to the list.
#
#
# World Telecommunication and Information Society Day (2022-05-17) has been added to the list.
#
#
# Lag BaOmer (2022-05-19) has been added to the list.
#
#
# World Bee Day (2022-05-20) has been added to the list.
#
#
# World Day for Cultural Diversity for Dialogue and Development (2022-05-21) has been added to the list.
#
#
# International Day for Biological Diversity (2022-05-22) has been added to the list.
#
#
# International Day to End Obstetric Fistula (2022-05-23) has been added to the list.
#
#
# African Liberation Day (2022-05-25) has been added to the list.
#
#
# Ascension Day (2022-05-26) has been added to the list.
#
#
# International Day of United Nations Peacekeepers (2022-05-29) has been added to the list.
#
#
# Memorial Day (2022-05-30) has been added to the list.
#
#
# World No Tobacco Day (2022-05-31) has been added to the list.
#
#
# Global Day of Parents (2022-06-01) has been added to the list.
#
#
# World Bicycle Day (2022-06-03) has been added to the list.
#
#
# International Day of Innocent Children Victims of Aggression (2022-06-04) has been added to the list.
#
#
# Pentecost (2022-06-05) has been added to the list.
#
#
# Whit Monday (2022-06-06) has been added to the list.
#
#
# World Food Safety Day (2022-06-07) has been added to the list.
#
#
# World Oceans Day (2022-06-08) has been added to the list.
#
#
# Kamehameha Day observed (2022-06-10) has been added to the list.
#
#
# Kamehameha Day (2022-06-11) has been added to the list.
#
#
# Trinity Sunday (2022-06-12) has been added to the list.
#
#
# International Albinism Awareness Day (2022-06-13) has been added to the list.
#
#
# World Blood Donor Day (2022-06-14) has been added to the list.
#
#
# World Elder Abuse Awareness Day (2022-06-15) has been added to the list.
#
#
# Corpus Christi (2022-06-16) has been added to the list.
#
#
# World Day to Combat Desertification and Drought (2022-06-17) has been added to the list.
#
#
# Sustainable Gastronomy Day (2022-06-18) has been added to the list.
#
#
# International Day for the Elimination of Sexual Violence in Conflict (2022-06-19) has been added to the list.
#
#
# World Refugee Day (2022-06-20) has been added to the list.
#
#
# International Day of Yoga (2022-06-21) has been added to the list.
#
#
# Public Service Day (2022-06-23) has been added to the list.
#
#
# Day of the Seafarer (2022-06-25) has been added to the list.
#
#
# International Day Against Drug Abuse and Illicit Trafficking (2022-06-26) has been added to the list.
#
#
# Micro-, Small and Medium-sized Enterprises Day (2022-06-27) has been added to the list.
#
#
# Carolina Day (2022-06-28) has been added to the list.
#
#
# International Day of the Tropics (2022-06-29) has been added to the list.
#
#
# International Asteroid Day (2022-06-30) has been added to the list.
#
#
# International Day of Cooperatives (2022-07-02) has been added to the list.
#
#
# Independence Day (2022-07-04) has been added to the list.
#
#
# Eid al-Adha (2022-07-09) has been added to the list.
#
#
# World Population Day (2022-07-11) has been added to the list.
#
#
# Nathan Bedford Forrest Day (2022-07-13) has been added to the list.
#
#
# Bastille Day (2022-07-14) has been added to the list.
#
#
# World Youth Skills Day (2022-07-15) has been added to the list.
#
#
# Rural Transit Day (2022-07-16) has been added to the list.
#
#
# Nelson Mandela Day (2022-07-18) has been added to the list.
#
#
# World Chess Day (2022-07-20) has been added to the list.
#
#
# Pioneer Day (2022-07-24) has been added to the list.
#
#
# World Drowning Prevention Day (2022-07-25) has been added to the list.
#
#
# Korean War Veteran Recognition Day (2022-07-27) has been added to the list.
#
#
# World Hepatitis Day (2022-07-28) has been added to the list.
#
#
# Muharram (2022-07-30) has been added to the list.
#
#
# Colorado Day (2022-08-01) has been added to the list.
#
#
# Coast Guard Birthday (2022-08-04) has been added to the list.
#
#
# Tisha B'Av (2022-08-07) has been added to the list.
#
#
# Ashura (Tentative Date) (2022-08-08) has been added to the list.
#
#
# International Day of the World's Indigenous People (2022-08-09) has been added to the list.
#
#
# Raksha Bandhan (2022-08-11) has been added to the list.
#
#
# International Youth Day (2022-08-12) has been added to the list.
#
#
# National Navajo Code Talkers Day (2022-08-14) has been added to the list.
#
#
# ...
#
#
# Linus Pauling Day (2024-02-28) has been added to the list.
#
#
# Leap Day (2024-02-29) has been added to the list.
#
#
# Zero Discrimination Day (2024-03-01) has been added to the list.
#
#
# Texas Independence Day (2024-03-02) has been added to the list.
#
#
# World Wildlife Day (2024-03-03) has been added to the list.
#
#
# Casimir Pulaski Day (2024-03-04) has been added to the list.
#
#
# Town Meeting Day (2024-03-05) has been added to the list.
#
#
# Maha Shivaratri (2024-03-08) has been added to the list.
#
#
# International Day of Women Judges (2024-03-10) has been added to the list.
#
#
# Ramadan Starts (2024-03-11) has been added to the list.
#
#
# World Kidney Day (2024-03-14) has been added to the list.
#
#
# St. Patrick's Day (2024-03-17) has been added to the list.
#
#
# Evacuation Day observed (2024-03-18) has been added to the list.
#
#
# March Equinox (2024-03-19) has been added to the list.
#
#
# French Language Day (2024-03-20) has been added to the list.
#
#
# International Day for the Elimination of Racial Discrimination (2024-03-21) has been added to the list.
#
#
# World Water Day (2024-03-22) has been added to the list.
#
#
# World Meteorological Day (2024-03-23) has been added to the list.
#
#
# Palm Sunday (2024-03-24) has been added to the list.
#
#
# Holi (2024-03-25) has been added to the list.
#
#
# Prince Jonah Kuhio Kalanianaole Day (2024-03-26) has been added to the list.
#
#
# Maundy Thursday (2024-03-28) has been added to the list.
#
#
# Good Friday (2024-03-29) has been added to the list.
#
#
# Holy Saturday (2024-03-30) has been added to the list.
#
#
# Easter Sunday (2024-03-31) has been added to the list.
#
#
# April Fool's Day (2024-04-01) has been added to the list.
#
#
# World Autism Awareness Day (2024-04-02) has been added to the list.
#
#
# United Nations' Mine Awareness Day (2024-04-04) has been added to the list.
#
#
# Lailat al-Qadr (2024-04-05) has been added to the list.
#
#
# International Day of Sport for Development and Peace (2024-04-06) has been added to the list.
#
#
# United Nations' World Health Day (2024-04-07) has been added to the list.
#
#
# National Library Workers' Day (2024-04-09) has been added to the list.
#
#
# Eid al-Fitr (Tentative Date) (2024-04-10) has been added to the list.
#
#
# International Day of Human Space Flight (2024-04-12) has been added to the list.
#
#
# Thomas Jefferson's Birthday (2024-04-13) has been added to the list.
#
#
# World Chagas Disease Day (2024-04-14) has been added to the list.
#
#
# Tax Day (2024-04-15) has been added to the list.
#
#
# Emancipation Day (2024-04-16) has been added to the list.
#
#
# International Day for Monuments and Sites (2024-04-18) has been added to the list.
#
#
# Arbor Day (2024-04-19) has been added to the list.
#
#
# Chinese Language Day (2024-04-20) has been added to the list.
#
#
# World Creativity and Innovation Day (2024-04-21) has been added to the list.
#
#
# Passover Eve (2024-04-22) has been added to the list.
#
#
# Passover (first day) (2024-04-23) has been added to the list.
#
#
# International Day of Multilateralism and Diplomacy for Peace (2024-04-24) has been added to the list.
#
#
# International Girls in ICT Day (2024-04-25) has been added to the list.
#
#
# World Intellectual Property Day (2024-04-26) has been added to the list.
#
#
# World Day for Safety and Health at Work (2024-04-28) has been added to the list.
#
#
# Arbor Day (2024-04-29) has been added to the list.
#
#
# Last Day of Passover (2024-04-30) has been added to the list.
#
#
# Law Day (2024-05-01) has been added to the list.
#
#
# World Tuna Day (2024-05-02) has been added to the list.
#
#
# Orthodox Good Friday (2024-05-03) has been added to the list.
#
#
# Orthodox Holy Saturday (2024-05-04) has been added to the list.
#
#
# Orthodox Easter (2024-05-05) has been added to the list.
#
#
# Yom HaShoah (2024-05-06) has been added to the list.
#
#
# National Teacher Appreciation Day (2024-05-07) has been added to the list.
#
#
# Time of Remembrance and Reconciliation for Those Who Lost Their Lives during the Second World War (2024-05-08) has been added to the list.
#
#
# Ascension Day (2024-05-09) has been added to the list.
#
#
# International Day of Argania (2024-05-10) has been added to the list.
#
#
# World Migratory Bird Day (2024-05-11) has been added to the list.
#
#
# International Nurses Day (2024-05-12) has been added to the list.
#
#
# Yom Ha'atzmaut (2024-05-14) has been added to the list.
#
#
# International Day of Families (2024-05-15) has been added to the list.
#
#
# International Day of Living Together in Peace (2024-05-16) has been added to the list.
#
#
# World Telecommunication and Information Society Day (2024-05-17) has been added to the list.
#
#
# Public Lands Day (2024-05-18) has been added to the list.
#
#
# Pentecost (2024-05-19) has been added to the list.
#
#
# Whit Monday (2024-05-20) has been added to the list.
#
#
# World Day for Cultural Diversity for Dialogue and Development (2024-05-21) has been added to the list.
#
#
# International Day for Biological Diversity (2024-05-22) has been added to the list.
#
#
# International Day to End Obstetric Fistula (2024-05-23) has been added to the list.
#
#
# African Liberation Day (2024-05-25) has been added to the list.
#
#
# Trinity Sunday (2024-05-26) has been added to the list.
#
#
# Memorial Day (2024-05-27) has been added to the list.
#
#
# International Day of United Nations Peacekeepers (2024-05-29) has been added to the list.
#
#
# Corpus Christi (2024-05-30) has been added to the list.
#
#
# World No Tobacco Day (2024-05-31) has been added to the list.
#
#
# Global Day of Parents (2024-06-01) has been added to the list.
#
#
# Native American Day (2024-06-02) has been added to the list.
#
#
# World Bicycle Day (2024-06-03) has been added to the list.
#
#
# International Day of Innocent Children Victims of Aggression (2024-06-04) has been added to the list.
#
#
# World Environment Day (2024-06-05) has been added to the list.
#
#
# Day of the Russian Language (2024-06-06) has been added to the list.
#
#
# World Food Safety Day (2024-06-07) has been added to the list.
#
#
# World Oceans Day (2024-06-08) has been added to the list.
#
#
# Kamehameha Day (2024-06-11) has been added to the list.
#
#
# Shavuot (2024-06-12) has been added to the list.
#
#
# International Albinism Awareness Day (2024-06-13) has been added to the list.
#
#
# World Blood Donor Day (2024-06-14) has been added to the list.
#
#
# World Elder Abuse Awareness Day (2024-06-15) has been added to the list.
#
#
# International Day of Family Remittances (2024-06-16) has been added to the list.
#
#
# Eid al-Adha (Tentative Date) (2024-06-17) has been added to the list.
#
#
# Sustainable Gastronomy Day (2024-06-18) has been added to the list.
#
#
# International Day for the Elimination of Sexual Violence in Conflict (2024-06-19) has been added to the list.
#
#
# World Refugee Day (2024-06-20) has been added to the list.
#
#
# International Day of Yoga (2024-06-21) has been added to the list.
#
#
# Public Service Day (2024-06-23) has been added to the list.
#
#
# Day of the Seafarer (2024-06-25) has been added to the list.
#
#
# International Day Against Drug Abuse and Illicit Trafficking (2024-06-26) has been added to the list.
#
#
# Micro-, Small and Medium-sized Enterprises Day (2024-06-27) has been added to the list.
#
#
# Carolina Day (2024-06-28) has been added to the list.
#
#
# International Day of the Tropics (2024-06-29) has been added to the list.
#
#
# International Asteroid Day (2024-06-30) has been added to the list.
#
#
# Independence Day (2024-07-04) has been added to the list.
#
#
# International Day of Cooperatives (2024-07-06) has been added to the list.
#
#
# Muharram (Tentative Date) (2024-07-08) has been added to the list.
#
#
# World Population Day (2024-07-11) has been added to the list.
#
#
# Nathan Bedford Forrest Day (2024-07-13) has been added to the list.
#
#
# Bastille Day (2024-07-14) has been added to the list.
#
#
# World Youth Skills Day (2024-07-15) has been added to the list.
#
#
# Rural Transit Day (2024-07-16) has been added to the list.
#
#
# Ashura (Tentative Date) (2024-07-17) has been added to the list.
#
#
# Nelson Mandela Day (2024-07-18) has been added to the list.
#
#
# World Chess Day (2024-07-20) has been added to the list.
#
#
# Pioneer Day (2024-07-24) has been added to the list.
#
#
# World Drowning Prevention Day (2024-07-25) has been added to the list.
#
#
# Korean War Veteran Recognition Day (2024-07-27) has been added to the list.
#
#
# World Hepatitis Day (2024-07-28) has been added to the list.
#
#
# International Day of Friendship (2024-07-30) has been added to the list.
#
#
# Colorado Day (2024-08-01) has been added to the list.
#
#
# Coast Guard Birthday (2024-08-04) has been added to the list.
#
#
# Purple Heart Day (2024-08-07) has been added to the list.
#
#
# International Day of the World's Indigenous People (2024-08-09) has been added to the list.
#
#
# International Youth Day (2024-08-12) has been added to the list.
#
#
# Tisha B'Av (2024-08-13) has been added to the list.
#
#
# Assumption of Mary (2024-08-15) has been added to the list.
#
#
# Hawaii Statehood Day (2024-08-16) has been added to the list.
#
#
# National Navajo Code Talkers Day (2024-08-18) has been added to the list.
#
#
# Raksha Bandhan (2024-08-19) has been added to the list.
#
#
# International Day of Remembrance of and Tribute to the Victims of Terrorism (2024-08-21) has been added to the list.
#
#
# International Day Commemorating the Victims of Acts of Violence Based on Religion or Belief (2024-08-22) has been added to the list.
#
#
# International Day for the Remembrance of the Slave Trade and its Abolition (2024-08-23) has been added to the list.
#
#
# Susan B. Anthony Day (2024-08-26) has been added to the list.
#
#
# Lyndon Baines Johnson Day (2024-08-27) has been added to the list.
#
#
# International Day against Nuclear Tests (2024-08-29) has been added to the list.
#
#
# International Day of the Victims of Enforced Disappearances (2024-08-30) has been added to the list.
#
#
# International Day for People of African Descent (2024-08-31) has been added to the list.
#
#
# Labor Day (2024-09-02) has been added to the list.
#
#
# World Sexual Health Day (2024-09-04) has been added to the list.
#
#
# International Day of Charity (2024-09-05) has been added to the list.
#
#
# Ganesh Chaturthi (2024-09-06) has been added to the list.
#
#
# International Day of Clean Air for Blue Skies (2024-09-07) has been added to the list.
#
#
# International Literacy Day (2024-09-08) has been added to the list.
#
#
# International Day to Protect Education from Attack (2024-09-09) has been added to the list.
#
#
# World Suicide Prevention Day (2024-09-10) has been added to the list.
#
#
# First Responders Day (2024-09-11) has been added to the list.
#
#
# International Day for South-South Cooperation (2024-09-12) has been added to the list.
#
#
# Friday the 13th (2024-09-13) has been added to the list.
#
#
# International Day of Democracy (2024-09-15) has been added to the list.
#
#
# The Prophet's Birthday (2024-09-16) has been added to the list.
#
#
# World Patient Safety Day (2024-09-17) has been added to the list.
#
#
# International Equal Pay Day (2024-09-18) has been added to the list.
#
#
# National POW/MIA Recognition Day (2024-09-20) has been added to the list.
#
#
# International Day of Peace (2024-09-21) has been added to the list.
#
#
# Emancipation Day (2024-09-22) has been added to the list.
#
#
# International Day of Sign Languages (2024-09-23) has been added to the list.
#
#
# World Maritime Day (2024-09-26) has been added to the list.
#
#
# World Tourism Day (2024-09-27) has been added to the list.
#
#
# International Day for Universal Access to Information (2024-09-28) has been added to the list.
#
#
# International Day of Awareness of Food Loss and Waste (2024-09-29) has been added to the list.
#
#
# International Translation Day (2024-09-30) has been added to the list.
#
#
# International Day of Older Persons (2024-10-01) has been added to the list.
#
#
# International Day of Non-Violence (2024-10-02) has been added to the list.
#
#
# Navratri (2024-10-03) has been added to the list.
#
#
# Feast of St Francis of Assisi (2024-10-04) has been added to the list.
#
#
# World Teachers' Day (2024-10-05) has been added to the list.
#
#
# World Cerebral Palsy Day (2024-10-06) has been added to the list.
#
#
# World Habitat Day (2024-10-07) has been added to the list.
#
#
# World Post Day (2024-10-09) has been added to the list.
#
#
# World Mental Health Day (2024-10-10) has been added to the list.
#
#
# International Day of the Girl Child (2024-10-11) has been added to the list.
#
#
# Dussehra (2024-10-12) has been added to the list.
#
#
# Navy Birthday (2024-10-13) has been added to the list.
#
#
# Columbus Day (2024-10-14) has been added to the list.
#
#
# International Day of Rural Women (2024-10-15) has been added to the list.
#
#
# World Food Day (2024-10-16) has been added to the list.
#
#
# First Day of Sukkot (2024-10-17) has been added to the list.
#
#
# Alaska Day (2024-10-18) has been added to the list.
#
#
# Sweetest Day (2024-10-19) has been added to the list.
#
#
# Last Day of Sukkot (2024-10-23) has been added to the list.
#
#
# Shmini Atzeret (2024-10-24) has been added to the list.
#
#
# Simchat Torah (2024-10-25) has been added to the list.
#
#
# World Day for Audiovisual Heritage (2024-10-27) has been added to the list.
#
#
# World Stroke Day (2024-10-29) has been added to the list.
#
#
# Diwali/Deepavali (2024-10-31) has been added to the list.
#
#
# All Saints' Day (2024-11-01) has been added to the list.
#
#
# All Souls' Day (2024-11-02) has been added to the list.
#
#
# New York City Marathon (2024-11-03) has been added to the list.
#
#
# World Tsunami Awareness Day (2024-11-05) has been added to the list.
#
#
# International Day for Preventing the Exploitation of the Environment in War and Armed Conflict (2024-11-06) has been added to the list.
#
#
# Return Day (2024-11-07) has been added to the list.
#
#
# World Science Day for Peace and Development (2024-11-10) has been added to the list.
#
#
# Barack Obama Day (2024-11-11) has been added to the list.
#
#
# World Pneumonia Day (2024-11-12) has been added to the list.
#
#
# World Diabetes Day (2024-11-14) has been added to the list.
#
#
# International Day for Tolerance (2024-11-16) has been added to the list.
#
#
# World Day of Remembrance for Road Traffic Victims (2024-11-17) has been added to the list.
#
#
# World Toilet Day (2024-11-19) has been added to the list.
#
#
# Universal Children's Day (2024-11-20) has been added to the list.
#
#
# World Television Day (2024-11-21) has been added to the list.
#
#
# International Day for the Elimination of Violence against Women (2024-11-25) has been added to the list.
#
#
# Thanksgiving Day (2024-11-28) has been added to the list.
#
#
# International Day of Solidarity with the Palestinian People (2024-11-29) has been added to the list.
#
#
# Day of Remembrance for all Victims of Chemical Warfare (2024-11-30) has been added to the list.
#
#
# First Sunday of Advent (2024-12-01) has been added to the list.
#
#
# International Day for the Abolition of Slavery (2024-12-02) has been added to the list.
#
#
# International Day of Persons with Disabilities (2024-12-03) has been added to the list.
#
#
# International Day of Banks (2024-12-04) has been added to the list.
#
#
# International Volunteer Day for Economic and Social Development (2024-12-05) has been added to the list.
#
#
# St Nicholas Day (2024-12-06) has been added to the list.
#
#
# International Civil Aviation Day (2024-12-07) has been added to the list.
#
#
# Feast of the Immaculate Conception (2024-12-09) has been added to the list.
#
#
# Human Rights Day (2024-12-10) has been added to the list.
#
#
# International Mountain Day (2024-12-11) has been added to the list.
#
#
# International Day of Neutrality (2024-12-12) has been added to the list.
#
#
# Friday the 13th (2024-12-13) has been added to the list.
#
#
# Bill of Rights Day (2024-12-15) has been added to the list.
#
#
# Pan American Aviation Day (2024-12-17) has been added to the list.
#
#
# International Migrants Day (2024-12-18) has been added to the list.
#
#
# International Human Solidarity Day (2024-12-20) has been added to the list.
#
#
# December Solstice (2024-12-21) has been added to the list.
#
#
# Christmas Eve (2024-12-24) has been added to the list.
#
#
# Christmas Day (2024-12-25) has been added to the list.
#
#
# Chanukah/Hanukkah (first day) (2024-12-26) has been added to the list.
#
#
# International Day of Epidemic Preparedness (2024-12-27) has been added to the list.
#
#
# New Year's Eve (2024-12-31) has been added to the list.

# %%
hol_list.inner_holidays
# Out:
# [Holiday(name="New Year's Day", date=datetime.date(2020, 1, 1)),
#  Holiday(name='World Braille Day', date=datetime.date(2020, 1, 4)),
#  Holiday(name='Epiphany', date=datetime.date(2020, 1, 6)),
#  Holiday(name="Asarah B'Tevet", date=datetime.date(2020, 1, 7)),
#  Holiday(name='Battle of New Orleans', date=datetime.date(2020, 1, 8)),
#  Holiday(name='Stephen Foster Memorial Day', date=datetime.date(2020, 1, 13)),
#  Holiday(name='Orthodox New Year', date=datetime.date(2020, 1, 14)),
#  Holiday(name='Lee-Jackson Day', date=datetime.date(2020, 1, 17)),
#  Holiday(name='World Religion Day', date=datetime.date(2020, 1, 19)),
#  Holiday(name='Martin Luther King Jr. Day', date=datetime.date(2020, 1, 20)),
#  Holiday(name='International Day of Education', date=datetime.date(2020, 1, 24)),
#  Holiday(name='Lunar New Year', date=datetime.date(2020, 1, 25)),
#  Holiday(name='International Customs Day', date=datetime.date(2020, 1, 26)),
#  Holiday(name='International Day of Commemoration in Memory of the Victims of the Holocaust', date=datetime.date(2020, 1, 27)),
#  Holiday(name='Kansas Day', date=datetime.date(2020, 1, 29)),
#  Holiday(name='National Freedom Day', date=datetime.date(2020, 2, 1)),
#  Holiday(name='World Wetlands Day', date=datetime.date(2020, 2, 2)),
#  Holiday(name='World Cancer Day', date=datetime.date(2020, 2, 4)),
#  Holiday(name='National Girls and Women in Sports Day', date=datetime.date(2020, 2, 5)),
#  Holiday(name='International Day of Zero Tolerance for Female Genital Mutilation', date=datetime.date(2020, 2, 6)),
#  Holiday(name='National Wear Red Day', date=datetime.date(2020, 2, 7)),
#  Holiday(name="Tu Bishvat/Tu B'Shevat", date=datetime.date(2020, 2, 10)),
#  Holiday(name='International Day of Women and Girls in Science', date=datetime.date(2020, 2, 11)),
#  Holiday(name="Lincoln's Birthday", date=datetime.date(2020, 2, 12)),
#  Holiday(name='World Radio Day', date=datetime.date(2020, 2, 13)),
#  Holiday(name="Valentine's Day", date=datetime.date(2020, 2, 14)),
#  Holiday(name="Susan B. Anthony's Birthday", date=datetime.date(2020, 2, 15)),
#  Holiday(name='Elizabeth Peratrovich Day', date=datetime.date(2020, 2, 16)),
#  Holiday(name="Presidents' Day", date=datetime.date(2020, 2, 17)),
#  Holiday(name='World Day of Social Justice', date=datetime.date(2020, 2, 20)),
#  Holiday(name='Maha Shivaratri', date=datetime.date(2020, 2, 21)),
#  Holiday(name='African-American Scientist and Inventor Day', date=datetime.date(2020, 2, 25)),
#  Holiday(name='Ash Wednesday', date=datetime.date(2020, 2, 26)),
#  Holiday(name='Linus Pauling Day', date=datetime.date(2020, 2, 28)),
#  Holiday(name='Leap Day', date=datetime.date(2020, 2, 29)),
#  Holiday(name='Zero Discrimination Day', date=datetime.date(2020, 3, 1)),
#  Holiday(name='Texas Independence Day', date=datetime.date(2020, 3, 2)),
#  Holiday(name='World Wildlife Day', date=datetime.date(2020, 3, 3)),
#  Holiday(name='Casimir Pulaski Day', date=datetime.date(2020, 3, 4)),
#  Holiday(name='Employee Appreciation Day', date=datetime.date(2020, 3, 6)),
#  Holiday(name="International Women's Day", date=datetime.date(2020, 3, 8)),
#  Holiday(name='Holi', date=datetime.date(2020, 3, 9)),
#  Holiday(name='Purim', date=datetime.date(2020, 3, 10)),
#  Holiday(name='World Kidney Day', date=datetime.date(2020, 3, 12)),
#  Holiday(name='Friday the 13th', date=datetime.date(2020, 3, 13)),
#  Holiday(name="St. Patrick's Day", date=datetime.date(2020, 3, 17)),
#  Holiday(name='First Day of Stay at Home Order', date=datetime.date(2020, 3, 19)),
#  Holiday(name='French Language Day', date=datetime.date(2020, 3, 20)),
#  Holiday(name='International Day for the Elimination of Racial Discrimination', date=datetime.date(2020, 3, 21)),
#  Holiday(name="Isra and Mi'raj", date=datetime.date(2020, 3, 22)),
#  Holiday(name='World Meteorological Day', date=datetime.date(2020, 3, 23)),
#  Holiday(name='World Tuberculosis Day', date=datetime.date(2020, 3, 24)),
#  Holiday(name='International Day of Remembrance of Slavery Victims and the Transatlantic Slave Trade', date=datetime.date(2020, 3, 25)),
#  Holiday(name='First Day of Stay at Home Order', date=datetime.date(2020, 3, 26)),
#  Holiday(name='First Day of Stay at Home Order', date=datetime.date(2020, 3, 27)),
#  Holiday(name='Earth Hour', date=datetime.date(2020, 3, 28)),
#  Holiday(name='First Day of Stay at Home Order', date=datetime.date(2020, 3, 29)),
#  Holiday(name='First Day of Stay at Home Order', date=datetime.date(2020, 3, 30)),
#  Holiday(name='First Day of Stay at Home Order', date=datetime.date(2020, 3, 31)),
#  Holiday(name="April Fool's Day", date=datetime.date(2020, 4, 1)),
#  Holiday(name='World Autism Awareness Day', date=datetime.date(2020, 4, 2)),
#  Holiday(name='First Day of Stay at Home Order', date=datetime.date(2020, 4, 3)),
#  Holiday(name="United Nations' Mine Awareness Day", date=datetime.date(2020, 4, 4)),
#  Holiday(name='Palm Sunday', date=datetime.date(2020, 4, 5)),
#  Holiday(name='International Day of Sport for Development and Peace', date=datetime.date(2020, 4, 6)),
#  Holiday(name="United Nations' World Health Day", date=datetime.date(2020, 4, 7)),
#  Holiday(name='Passover Eve', date=datetime.date(2020, 4, 8)),
#  Holiday(name='Maundy Thursday', date=datetime.date(2020, 4, 9)),
#  Holiday(name='Good Friday', date=datetime.date(2020, 4, 10)),
#  Holiday(name='Holy Saturday', date=datetime.date(2020, 4, 11)),
#  Holiday(name='International Day of Human Space Flight', date=datetime.date(2020, 4, 12)),
#  Holiday(name='Easter Monday', date=datetime.date(2020, 4, 13)),
#  Holiday(name='World Chagas Disease Day', date=datetime.date(2020, 4, 14)),
#  Holiday(name='Father Damien Day', date=datetime.date(2020, 4, 15)),
#  Holiday(name='Last Day of Passover', date=datetime.date(2020, 4, 16)),
#  Holiday(name='Orthodox Good Friday', date=datetime.date(2020, 4, 17)),
#  Holiday(name='Orthodox Holy Saturday', date=datetime.date(2020, 4, 18)),
#  Holiday(name='Orthodox Easter', date=datetime.date(2020, 4, 19)),
#  Holiday(name='Orthodox Easter Monday', date=datetime.date(2020, 4, 20)),
#  Holiday(name='Yom HaShoah', date=datetime.date(2020, 4, 21)),
#  Holiday(name='Earth Day', date=datetime.date(2020, 4, 22)),
#  Holiday(name='World Book and Copyright Day', date=datetime.date(2020, 4, 23)),
#  Holiday(name='Ramadan Starts', date=datetime.date(2020, 4, 24)),
#  Holiday(name="International Delegate's Day", date=datetime.date(2020, 4, 25)),
#  Holiday(name='World Intellectual Property Day', date=datetime.date(2020, 4, 26)),
#  Holiday(name='Arbor Day', date=datetime.date(2020, 4, 27)),
#  Holiday(name='World Day for Safety and Health at Work', date=datetime.date(2020, 4, 28)),
#  Holiday(name="Yom Ha'atzmaut", date=datetime.date(2020, 4, 29)),
#  Holiday(name='International Jazz Day', date=datetime.date(2020, 4, 30)),
#  Holiday(name='Last Day of Stay at Home Directive', date=datetime.date(2020, 5, 1)),
#  Holiday(name='World Tuna Day', date=datetime.date(2020, 5, 2)),
#  Holiday(name='World Press Freedom Day', date=datetime.date(2020, 5, 3)),
#  Holiday(name='Last Day of Stay at Home Order', date=datetime.date(2020, 5, 4)),
#  Holiday(name='World Portuguese Language Day', date=datetime.date(2020, 5, 5)),
#  Holiday(name='National Nurses Day', date=datetime.date(2020, 5, 6)),
#  Holiday(name='Day of Vesak', date=datetime.date(2020, 5, 7)),
#  Holiday(name='Time of Remembrance and Reconciliation for Those Who Lost Their Lives during the Second World War', date=datetime.date(2020, 5, 8)),
#  Holiday(name='World Migratory Bird Day', date=datetime.date(2020, 5, 9)),
#  Holiday(name="Mother's Day", date=datetime.date(2020, 5, 10)),
#  Holiday(name='Confederate Memorial Day observed', date=datetime.date(2020, 5, 11)),
#  Holiday(name='Lag BaOmer', date=datetime.date(2020, 5, 12)),
#  Holiday(name='Last Day of Stay at Home Order', date=datetime.date(2020, 5, 13)),
#  Holiday(name='International Day of Families', date=datetime.date(2020, 5, 15)),
#  Holiday(name='International Day of Living Together in Peace', date=datetime.date(2020, 5, 16)),
#  Holiday(name='World Telecommunication and Information Society Day', date=datetime.date(2020, 5, 17)),
#  Holiday(name='Last Day of Stay at Home Advisory', date=datetime.date(2020, 5, 18)),
#  Holiday(name='Lailat al-Qadr', date=datetime.date(2020, 5, 19)),
#  Holiday(name='World Bee Day', date=datetime.date(2020, 5, 20)),
#  Holiday(name='Ascension Day', date=datetime.date(2020, 5, 21)),
#  Holiday(name='International Day for Biological Diversity', date=datetime.date(2020, 5, 22)),
#  Holiday(name='International Day to End Obstetric Fistula', date=datetime.date(2020, 5, 23)),
#  Holiday(name='Eid al-Fitr', date=datetime.date(2020, 5, 24)),
#  Holiday(name='African Liberation Day', date=datetime.date(2020, 5, 25)),
#  Holiday(name='Shavuot', date=datetime.date(2020, 5, 29)),
#  Holiday(name='Last Day of Stay at Home Order', date=datetime.date(2020, 5, 30)),
#  Holiday(name='Pentecost', date=datetime.date(2020, 5, 31)),
#  Holiday(name='Whit Monday', date=datetime.date(2020, 6, 1)),
#  Holiday(name='World Bicycle Day', date=datetime.date(2020, 6, 3)),
#  Holiday(name='International Day of Innocent Children Victims of Aggression', date=datetime.date(2020, 6, 4)),
#  Holiday(name='World Environment Day', date=datetime.date(2020, 6, 5)),
#  Holiday(name='Day of the Russian Language', date=datetime.date(2020, 6, 6)),
#  Holiday(name='Trinity Sunday', date=datetime.date(2020, 6, 7)),
#  Holiday(name='World Oceans Day', date=datetime.date(2020, 6, 8)),
#  Holiday(name='Primary Election Day', date=datetime.date(2020, 6, 9)),
#  Holiday(name='Last Day of Stay at Home Order', date=datetime.date(2020, 6, 10)),
#  Holiday(name='Corpus Christi', date=datetime.date(2020, 6, 11)),
#  Holiday(name='World Day Against Child Labour', date=datetime.date(2020, 6, 12)),
#  Holiday(name='International Albinism Awareness Day', date=datetime.date(2020, 6, 13)),
#  Holiday(name='World Blood Donor Day', date=datetime.date(2020, 6, 14)),
#  Holiday(name='World Elder Abuse Awareness Day', date=datetime.date(2020, 6, 15)),
#  Holiday(name='International Day of Family Remittances', date=datetime.date(2020, 6, 16)),
#  Holiday(name='World Day to Combat Desertification and Drought', date=datetime.date(2020, 6, 17)),
#  Holiday(name='Sustainable Gastronomy Day', date=datetime.date(2020, 6, 18)),
#  Holiday(name='International Day for the Elimination of Sexual Violence in Conflict', date=datetime.date(2020, 6, 19)),
#  Holiday(name='World Refugee Day', date=datetime.date(2020, 6, 20)),
#  Holiday(name='International Day of Yoga', date=datetime.date(2020, 6, 21)),
#  Holiday(name='Public Service Day', date=datetime.date(2020, 6, 23)),
#  Holiday(name='Day of the Seafarer', date=datetime.date(2020, 6, 25)),
#  Holiday(name='International Day Against Drug Abuse and Illicit Trafficking', date=datetime.date(2020, 6, 26)),
#  Holiday(name='Micro-, Small and Medium-sized Enterprises Day', date=datetime.date(2020, 6, 27)),
#  Holiday(name='Carolina Day', date=datetime.date(2020, 6, 28)),
#  Holiday(name='International Day of the Tropics', date=datetime.date(2020, 6, 29)),
#  Holiday(name='International Asteroid Day', date=datetime.date(2020, 6, 30)),
#  Holiday(name='Independence Day (substitute)', date=datetime.date(2020, 7, 3)),
#  Holiday(name='International Day of Cooperatives', date=datetime.date(2020, 7, 4)),
#  Holiday(name='World Population Day', date=datetime.date(2020, 7, 11)),
#  Holiday(name='Nathan Bedford Forrest Day', date=datetime.date(2020, 7, 13)),
#  Holiday(name='Bastille Day', date=datetime.date(2020, 7, 14)),
#  Holiday(name='World Youth Skills Day', date=datetime.date(2020, 7, 15)),
#  Holiday(name='Rural Transit Day', date=datetime.date(2020, 7, 16)),
#  Holiday(name='Nelson Mandela Day', date=datetime.date(2020, 7, 18)),
#  Holiday(name='World Chess Day', date=datetime.date(2020, 7, 20)),
#  Holiday(name='Pioneer Day', date=datetime.date(2020, 7, 24)),
#  Holiday(name="Parents' Day", date=datetime.date(2020, 7, 26)),
#  Holiday(name='Korean War Veteran Recognition Day', date=datetime.date(2020, 7, 27)),
#  Holiday(name='World Hepatitis Day', date=datetime.date(2020, 7, 28)),
#  Holiday(name="Tisha B'Av", date=datetime.date(2020, 7, 30)),
#  Holiday(name='Eid al-Adha', date=datetime.date(2020, 7, 31)),
#  Holiday(name='Colorado Day', date=datetime.date(2020, 8, 1)),
#  Holiday(name='American Family Day', date=datetime.date(2020, 8, 2)),
#  Holiday(name='Raksha Bandhan', date=datetime.date(2020, 8, 3)),
#  Holiday(name='Coast Guard Birthday', date=datetime.date(2020, 8, 4)),
#  Holiday(name='Purple Heart Day', date=datetime.date(2020, 8, 7)),
#  Holiday(name="International Day of the World's Indigenous People", date=datetime.date(2020, 8, 9)),
#  Holiday(name='Janmashtami', date=datetime.date(2020, 8, 10)),
#  Holiday(name='International Youth Day', date=datetime.date(2020, 8, 12)),
#  Holiday(name='Assumption of Mary', date=datetime.date(2020, 8, 15)),
#  Holiday(name='National Navajo Code Talkers Day', date=datetime.date(2020, 8, 16)),
#  Holiday(name='Bennington Battle Day observed', date=datetime.date(2020, 8, 17)),
#  Holiday(name='World Humanitarian Day', date=datetime.date(2020, 8, 19)),
#  Holiday(name='Muharram', date=datetime.date(2020, 8, 20)),
#  Holiday(name='Ganesh Chaturthi', date=datetime.date(2020, 8, 21)),
#  Holiday(name='International Day Commemorating the Victims of Acts of Violence Based on Religion or Belief', date=datetime.date(2020, 8, 22)),
#  Holiday(name='International Day for the Remembrance of the Slave Trade and its Abolition', date=datetime.date(2020, 8, 23)),
#  Holiday(name='Susan B. Anthony Day', date=datetime.date(2020, 8, 26)),
#  Holiday(name='Lyndon Baines Johnson Day', date=datetime.date(2020, 8, 27)),
#  Holiday(name='Last Day of Stay at Home Instructions', date=datetime.date(2020, 8, 28)),
#  Holiday(name='Ashura', date=datetime.date(2020, 8, 29)),
#  Holiday(name='International Day of the Victims of Enforced Disappearances', date=datetime.date(2020, 8, 30)),
#  Holiday(name='International Overdose Awareness Day', date=datetime.date(2020, 8, 31)),
#  Holiday(name='World Sexual Health Day', date=datetime.date(2020, 9, 4)),
#  Holiday(name='International Day of Charity', date=datetime.date(2020, 9, 5)),
#  Holiday(name='International Day of Clean Air for Blue Skies', date=datetime.date(2020, 9, 7)),
#  Holiday(name='International Literacy Day', date=datetime.date(2020, 9, 8)),
#  Holiday(name='International Day to Protect Education from Attack', date=datetime.date(2020, 9, 9)),
#  Holiday(name='World Suicide Prevention Day', date=datetime.date(2020, 9, 10)),
#  Holiday(name='First Responders Day', date=datetime.date(2020, 9, 11)),
#  Holiday(name='International Day for South-South Cooperation', date=datetime.date(2020, 9, 12)),
#  Holiday(name='National Grandparents Day', date=datetime.date(2020, 9, 13)),
#  Holiday(name='International Day of Democracy', date=datetime.date(2020, 9, 15)),
#  Holiday(name='International Day for the Preservation of the Ozone Layer', date=datetime.date(2020, 9, 16)),
#  Holiday(name='World Patient Safety Day', date=datetime.date(2020, 9, 17)),
#  Holiday(name='International Equal Pay Day', date=datetime.date(2020, 9, 18)),
#  Holiday(name='Rosh Hashana', date=datetime.date(2020, 9, 19)),
#  Holiday(name='International Day of Peace', date=datetime.date(2020, 9, 21)),
#  Holiday(name='Emancipation Day', date=datetime.date(2020, 9, 22)),
#  Holiday(name='International Day of Sign Languages', date=datetime.date(2020, 9, 23)),
#  Holiday(name='World Maritime Day', date=datetime.date(2020, 9, 24)),
#  Holiday(name='Native American Day', date=datetime.date(2020, 9, 25)),
#  Holiday(name='International Day for the Total Elimination of Nuclear Weapons', date=datetime.date(2020, 9, 26)),
#  Holiday(name='World Tourism Day', date=datetime.date(2020, 9, 27)),
#  Holiday(name='Yom Kippur', date=datetime.date(2020, 9, 28)),
#  Holiday(name='International Day of Awareness of Food Loss and Waste', date=datetime.date(2020, 9, 29)),
#  Holiday(name='International Translation Day', date=datetime.date(2020, 9, 30)),
#  Holiday(name='International Day of Older Persons', date=datetime.date(2020, 10, 1)),
#  Holiday(name='International Day of Non-Violence', date=datetime.date(2020, 10, 2)),
#  Holiday(name='First Day of Sukkot', date=datetime.date(2020, 10, 3)),
#  Holiday(name='Feast of St Francis of Assisi', date=datetime.date(2020, 10, 4)),
#  Holiday(name="World Teachers' Day", date=datetime.date(2020, 10, 5)),
#  Holiday(name='World Cerebral Palsy Day', date=datetime.date(2020, 10, 6)),
#  Holiday(name='World Sight Day', date=datetime.date(2020, 10, 8)),
#  Holiday(name='Last Day of Sukkot', date=datetime.date(2020, 10, 9)),
#  Holiday(name='Shmini Atzeret', date=datetime.date(2020, 10, 10)),
#  Holiday(name='Simchat Torah', date=datetime.date(2020, 10, 11)),
#  Holiday(name='World Spanish Language Day', date=datetime.date(2020, 10, 12)),
#  Holiday(name='Navy Birthday', date=datetime.date(2020, 10, 13)),
#  Holiday(name='International Day for Natural Disaster Reduction', date=datetime.date(2020, 10, 14)),
#  Holiday(name='International Day of Rural Women', date=datetime.date(2020, 10, 15)),
#  Holiday(name='World Food Day', date=datetime.date(2020, 10, 16)),
#  Holiday(name='Navratri', date=datetime.date(2020, 10, 17)),
#  Holiday(name='Alaska Day', date=datetime.date(2020, 10, 18)),
#  Holiday(name='Alaska Day observed', date=datetime.date(2020, 10, 19)),
#  Holiday(name='World Statistics Day', date=datetime.date(2020, 10, 20)),
#  Holiday(name='United Nations Day', date=datetime.date(2020, 10, 24)),
#  Holiday(name='Dussehra', date=datetime.date(2020, 10, 25)),
#  Holiday(name='World Day for Audiovisual Heritage', date=datetime.date(2020, 10, 27)),
#  Holiday(name="The Prophet's Birthday", date=datetime.date(2020, 10, 29)),
#  Holiday(name='Nevada Day', date=datetime.date(2020, 10, 30)),
#  Holiday(name='World Cities Day', date=datetime.date(2020, 10, 31)),
#  Holiday(name="All Saints' Day", date=datetime.date(2020, 11, 1)),
#  Holiday(name="All Souls' Day", date=datetime.date(2020, 11, 2)),
#  Holiday(name='Election Day (General Election)', date=datetime.date(2020, 11, 3)),
#  Holiday(name='World Tsunami Awareness Day', date=datetime.date(2020, 11, 5)),
#  Holiday(name='International Day for Preventing the Exploitation of the Environment in War and Armed Conflict', date=datetime.date(2020, 11, 6)),
#  Holiday(name='Barack Obama Day', date=datetime.date(2020, 11, 9)),
#  Holiday(name='World Science Day for Peace and Development', date=datetime.date(2020, 11, 10)),
#  Holiday(name='Veterans Day', date=datetime.date(2020, 11, 11)),
#  Holiday(name='World Pneumonia Day', date=datetime.date(2020, 11, 12)),
#  Holiday(name='Friday the 13th', date=datetime.date(2020, 11, 13)),
#  Holiday(name='Diwali/Deepavali', date=datetime.date(2020, 11, 14)),
#  Holiday(name='World Day of Remembrance for Road Traffic Victims', date=datetime.date(2020, 11, 15)),
#  Holiday(name='International Day for Tolerance', date=datetime.date(2020, 11, 16)),
#  Holiday(name='World Prematurity Day', date=datetime.date(2020, 11, 17)),
#  Holiday(name='World Philosophy Day', date=datetime.date(2020, 11, 19)),
#  Holiday(name="Universal Children's Day", date=datetime.date(2020, 11, 20)),
#  Holiday(name='World Television Day', date=datetime.date(2020, 11, 21)),
#  Holiday(name='International Day for the Elimination of Violence against Women', date=datetime.date(2020, 11, 25)),
#  Holiday(name='Thanksgiving Day', date=datetime.date(2020, 11, 26)),
#  Holiday(name='State Holiday', date=datetime.date(2020, 11, 27)),
#  Holiday(name='First Sunday of Advent', date=datetime.date(2020, 11, 29)),
#  Holiday(name='Day of Remembrance for all Victims of Chemical Warfare', date=datetime.date(2020, 11, 30)),
#  Holiday(name='World AIDS Day', date=datetime.date(2020, 12, 1)),
#  Holiday(name='International Day for the Abolition of Slavery', date=datetime.date(2020, 12, 2)),
#  Holiday(name='International Day of Persons with Disabilities', date=datetime.date(2020, 12, 3)),
#  Holiday(name='International Day of Banks', date=datetime.date(2020, 12, 4)),
#  Holiday(name='International Volunteer Day for Economic and Social Development', date=datetime.date(2020, 12, 5)),
#  Holiday(name='St Nicholas Day', date=datetime.date(2020, 12, 6)),
#  Holiday(name='International Civil Aviation Day', date=datetime.date(2020, 12, 7)),
#  Holiday(name='Feast of the Immaculate Conception', date=datetime.date(2020, 12, 8)),
#  Holiday(name='International Anti-Corruption Day', date=datetime.date(2020, 12, 9)),
#  Holiday(name='Human Rights Day', date=datetime.date(2020, 12, 10)),
#  Holiday(name='Chanukah/Hanukkah (first day)', date=datetime.date(2020, 12, 11)),
#  Holiday(name='International Day of Neutrality', date=datetime.date(2020, 12, 12)),
#  Holiday(name='National Guard Birthday', date=datetime.date(2020, 12, 13)),
#  Holiday(name='Bill of Rights Day', date=datetime.date(2020, 12, 15)),
#  Holiday(name='Pan American Aviation Day', date=datetime.date(2020, 12, 17)),
#  Holiday(name='Last Day of Chanukah', date=datetime.date(2020, 12, 18)),
#  Holiday(name='International Human Solidarity Day', date=datetime.date(2020, 12, 20)),
#  Holiday(name='December Solstice', date=datetime.date(2020, 12, 21)),
#  Holiday(name='Christmas Eve', date=datetime.date(2020, 12, 24)),
#  Holiday(name="Asarah B'Tevet", date=datetime.date(2020, 12, 25)),
#  Holiday(name='Kwanzaa (first day)', date=datetime.date(2020, 12, 26)),
#  Holiday(name='International Day of Epidemic Preparedness', date=datetime.date(2020, 12, 27)),
#  Holiday(name="New Year's Eve", date=datetime.date(2020, 12, 31)),
#  Holiday(name="New Year's Day", date=datetime.date(2021, 1, 1)),
#  Holiday(name='World Braille Day', date=datetime.date(2021, 1, 4)),
#  Holiday(name='Epiphany', date=datetime.date(2021, 1, 6)),
#  Holiday(name='Orthodox Christmas Day', date=datetime.date(2021, 1, 7)),
#  Holiday(name='Battle of New Orleans', date=datetime.date(2021, 1, 8)),
#  Holiday(name='Stephen Foster Memorial Day', date=datetime.date(2021, 1, 13)),
#  Holiday(name='Orthodox New Year', date=datetime.date(2021, 1, 14)),
#  Holiday(name='World Religion Day', date=datetime.date(2021, 1, 17)),
#  Holiday(name='Martin Luther King Jr. Day', date=datetime.date(2021, 1, 18)),
#  Holiday(name="Robert E. Lee's Birthday", date=datetime.date(2021, 1, 19)),
#  Holiday(name='Inauguration Day', date=datetime.date(2021, 1, 20)),
#  Holiday(name='International Day of Education', date=datetime.date(2021, 1, 24)),
#  Holiday(name='International Customs Day', date=datetime.date(2021, 1, 26)),
#  Holiday(name='International Day of Commemoration in Memory of the Victims of the Holocaust', date=datetime.date(2021, 1, 27)),
#  Holiday(name="Tu Bishvat/Tu B'Shevat", date=datetime.date(2021, 1, 28)),
#  Holiday(name='Kansas Day', date=datetime.date(2021, 1, 29)),
#  Holiday(name='World Leprosy Day', date=datetime.date(2021, 1, 31)),
#  Holiday(name='National Freedom Day', date=datetime.date(2021, 2, 1)),
#  Holiday(name='World Wetlands Day', date=datetime.date(2021, 2, 2)),
#  Holiday(name='National Girls and Women in Sports Day', date=datetime.date(2021, 2, 3)),
#  Holiday(name='International Day of Human Fraternity', date=datetime.date(2021, 2, 4)),
#  Holiday(name='National Wear Red Day', date=datetime.date(2021, 2, 5)),
#  Holiday(name='International Day of Zero Tolerance for Female Genital Mutilation', date=datetime.date(2021, 2, 6)),
#  Holiday(name='Super Bowl', date=datetime.date(2021, 2, 7)),
#  Holiday(name='World Pulses Day', date=datetime.date(2021, 2, 10)),
#  Holiday(name='International Day of Women and Girls in Science', date=datetime.date(2021, 2, 11)),
#  Holiday(name="Lincoln's Birthday", date=datetime.date(2021, 2, 12)),
#  Holiday(name='World Radio Day', date=datetime.date(2021, 2, 13)),
#  Holiday(name="Valentine's Day", date=datetime.date(2021, 2, 14)),
#  Holiday(name="Presidents' Day", date=datetime.date(2021, 2, 15)),
#  Holiday(name='Shrove Tuesday/Mardi Gras', date=datetime.date(2021, 2, 16)),
#  Holiday(name='Ash Wednesday', date=datetime.date(2021, 2, 17)),
#  Holiday(name='World Day of Social Justice', date=datetime.date(2021, 2, 20)),
#  Holiday(name='International Mother Language Day', date=datetime.date(2021, 2, 21)),
#  Holiday(name='African-American Scientist and Inventor Day', date=datetime.date(2021, 2, 25)),
#  Holiday(name='Purim', date=datetime.date(2021, 2, 26)),
#  Holiday(name='Linus Pauling Day', date=datetime.date(2021, 2, 28)),
#  Holiday(name='Zero Discrimination Day', date=datetime.date(2021, 3, 1)),
#  Holiday(name='Texas Independence Day', date=datetime.date(2021, 3, 2)),
#  Holiday(name='World Wildlife Day', date=datetime.date(2021, 3, 3)),
#  Holiday(name='Casimir Pulaski Day', date=datetime.date(2021, 3, 4)),
#  Holiday(name='Employee Appreciation Day', date=datetime.date(2021, 3, 5)),
#  Holiday(name="International Women's Day", date=datetime.date(2021, 3, 8)),
#  Holiday(name='Maha Shivaratri', date=datetime.date(2021, 3, 11)),
#  Holiday(name='Daylight Saving Time starts', date=datetime.date(2021, 3, 14)),
#  Holiday(name="St. Patrick's Day", date=datetime.date(2021, 3, 17)),
#  Holiday(name='French Language Day', date=datetime.date(2021, 3, 20)),
#  Holiday(name='International Day for the Elimination of Racial Discrimination', date=datetime.date(2021, 3, 21)),
#  Holiday(name='World Water Day', date=datetime.date(2021, 3, 22)),
#  Holiday(name='World Meteorological Day', date=datetime.date(2021, 3, 23)),
#  Holiday(name='World Tuberculosis Day', date=datetime.date(2021, 3, 24)),
#  Holiday(name='International Day of Remembrance of Slavery Victims and the Transatlantic Slave Trade', date=datetime.date(2021, 3, 25)),
#  Holiday(name='Prince Jonah Kuhio Kalanianaole Day', date=datetime.date(2021, 3, 26)),
#  Holiday(name='Passover Eve', date=datetime.date(2021, 3, 27)),
#  Holiday(name='Palm Sunday', date=datetime.date(2021, 3, 28)),
#  Holiday(name="Seward's Day", date=datetime.date(2021, 3, 29)),
#  Holiday(name='Wyoming Veterans Welcome Home Day', date=datetime.date(2021, 3, 30)),
#  Holiday(name='César Chávez Day', date=datetime.date(2021, 3, 31)),
#  Holiday(name='Maundy Thursday', date=datetime.date(2021, 4, 1)),
#  Holiday(name='World Autism Awareness Day', date=datetime.date(2021, 4, 2)),
#  Holiday(name='Holy Saturday', date=datetime.date(2021, 4, 3)),
#  Holiday(name='Last Day of Passover', date=datetime.date(2021, 4, 4)),
#  Holiday(name='International Day of Conscience', date=datetime.date(2021, 4, 5)),
#  Holiday(name='International Day of Sport for Development and Peace', date=datetime.date(2021, 4, 6)),
#  Holiday(name="United Nations' World Health Day", date=datetime.date(2021, 4, 7)),
#  Holiday(name='Yom HaShoah', date=datetime.date(2021, 4, 8)),
#  Holiday(name='International Day of Human Space Flight', date=datetime.date(2021, 4, 12)),
#  Holiday(name='Ramadan Starts', date=datetime.date(2021, 4, 13)),
#  Holiday(name='World Chagas Disease Day', date=datetime.date(2021, 4, 14)),
#  Holiday(name="Yom Ha'atzmaut", date=datetime.date(2021, 4, 15)),
#  Holiday(name='Emancipation Day', date=datetime.date(2021, 4, 16)),
#  Holiday(name='International Day for Monuments and Sites', date=datetime.date(2021, 4, 18)),
#  Holiday(name="Patriots' Day", date=datetime.date(2021, 4, 19)),
#  Holiday(name='Chinese Language Day', date=datetime.date(2021, 4, 20)),
#  Holiday(name='World Creativity and Innovation Day', date=datetime.date(2021, 4, 21)),
#  Holiday(name='International Girls in ICT Day', date=datetime.date(2021, 4, 22)),
#  Holiday(name='World Book and Copyright Day', date=datetime.date(2021, 4, 23)),
#  Holiday(name='International Day of Multilateralism and Diplomacy for Peace', date=datetime.date(2021, 4, 24)),
#  Holiday(name="International Delegate's Day", date=datetime.date(2021, 4, 25)),
#  Holiday(name='World Intellectual Property Day', date=datetime.date(2021, 4, 26)),
#  Holiday(name='World Day for Safety and Health at Work', date=datetime.date(2021, 4, 28)),
#  Holiday(name='Lag BaOmer', date=datetime.date(2021, 4, 30)),
#  Holiday(name='Orthodox Holy Saturday', date=datetime.date(2021, 5, 1)),
#  Holiday(name='Orthodox Easter', date=datetime.date(2021, 5, 2)),
#  Holiday(name='Orthodox Easter Monday', date=datetime.date(2021, 5, 3)),
#  Holiday(name='Kent State Shootings Remembrance', date=datetime.date(2021, 5, 4)),
#  Holiday(name='World Portuguese Language Day', date=datetime.date(2021, 5, 5)),
#  Holiday(name='National Nurses Day', date=datetime.date(2021, 5, 6)),
#  Holiday(name='Truman Day observed', date=datetime.date(2021, 5, 7)),
#  Holiday(name='Lailat al-Qadr', date=datetime.date(2021, 5, 8)),
#  Holiday(name="Mother's Day", date=datetime.date(2021, 5, 9)),
#  Holiday(name='International Day of Argania', date=datetime.date(2021, 5, 10)),
#  Holiday(name='International Nurses Day', date=datetime.date(2021, 5, 12)),
#  Holiday(name='Ascension Day', date=datetime.date(2021, 5, 13)),
#  Holiday(name='Native American Day', date=datetime.date(2021, 5, 14)),
#  Holiday(name='International Day of Families', date=datetime.date(2021, 5, 15)),
#  Holiday(name='International Day of Living Together in Peace', date=datetime.date(2021, 5, 16)),
#  Holiday(name='Shavuot', date=datetime.date(2021, 5, 17)),
#  Holiday(name='Emergency Medical Services for Children Day', date=datetime.date(2021, 5, 19)),
#  Holiday(name='World Bee Day', date=datetime.date(2021, 5, 20)),
#  Holiday(name='World Day for Cultural Diversity for Dialogue and Development', date=datetime.date(2021, 5, 21)),
#  Holiday(name='International Day for Biological Diversity', date=datetime.date(2021, 5, 22)),
#  Holiday(name='Pentecost', date=datetime.date(2021, 5, 23)),
#  Holiday(name='Whit Monday', date=datetime.date(2021, 5, 24)),
#  Holiday(name='African Liberation Day', date=datetime.date(2021, 5, 25)),
#  Holiday(name='Day of Vesak', date=datetime.date(2021, 5, 26)),
#  Holiday(name='International Day of United Nations Peacekeepers', date=datetime.date(2021, 5, 29)),
#  Holiday(name='Trinity Sunday', date=datetime.date(2021, 5, 30)),
#  Holiday(name='World No Tobacco Day', date=datetime.date(2021, 5, 31)),
#  Holiday(name='Global Day of Parents', date=datetime.date(2021, 6, 1)),
#  Holiday(name='Corpus Christi', date=datetime.date(2021, 6, 3)),
#  Holiday(name='International Day of Innocent Children Victims of Aggression', date=datetime.date(2021, 6, 4)),
#  Holiday(name='World Environment Day', date=datetime.date(2021, 6, 5)),
#  Holiday(name='Day of the Russian Language', date=datetime.date(2021, 6, 6)),
#  Holiday(name='World Food Safety Day', date=datetime.date(2021, 6, 7)),
#  Holiday(name='World Oceans Day', date=datetime.date(2021, 6, 8)),
#  Holiday(name='Kamehameha Day', date=datetime.date(2021, 6, 11)),
#  Holiday(name='World Day Against Child Labour', date=datetime.date(2021, 6, 12)),
#  Holiday(name='International Albinism Awareness Day', date=datetime.date(2021, 6, 13)),
#  Holiday(name='World Blood Donor Day', date=datetime.date(2021, 6, 14)),
#  Holiday(name='World Elder Abuse Awareness Day', date=datetime.date(2021, 6, 15)),
#  Holiday(name='International Day of Family Remittances', date=datetime.date(2021, 6, 16)),
#  Holiday(name='World Day to Combat Desertification and Drought', date=datetime.date(2021, 6, 17)),
#  Holiday(name='Sustainable Gastronomy Day', date=datetime.date(2021, 6, 18)),
#  Holiday(name='International Day for the Elimination of Sexual Violence in Conflict', date=datetime.date(2021, 6, 19)),
#  Holiday(name='World Refugee Day', date=datetime.date(2021, 6, 20)),
#  Holiday(name='International Day of Yoga', date=datetime.date(2021, 6, 21)),
#  Holiday(name='Public Service Day', date=datetime.date(2021, 6, 23)),
#  Holiday(name='Day of the Seafarer', date=datetime.date(2021, 6, 25)),
#  Holiday(name='International Day Against Drug Abuse and Illicit Trafficking', date=datetime.date(2021, 6, 26)),
#  Holiday(name='Micro-, Small and Medium-sized Enterprises Day', date=datetime.date(2021, 6, 27)),
#  Holiday(name='Carolina Day', date=datetime.date(2021, 6, 28)),
#  Holiday(name='International Day of the Tropics', date=datetime.date(2021, 6, 29)),
#  Holiday(name='International Asteroid Day', date=datetime.date(2021, 6, 30)),
#  Holiday(name='International Day of Cooperatives', date=datetime.date(2021, 7, 3)),
#  Holiday(name='Independence Day', date=datetime.date(2021, 7, 4)),
#  Holiday(name='Independence Day (substitute)', date=datetime.date(2021, 7, 5)),
#  Holiday(name='World Population Day', date=datetime.date(2021, 7, 11)),
#  Holiday(name='Nathan Bedford Forrest Day', date=datetime.date(2021, 7, 13)),
#  Holiday(name='Bastille Day', date=datetime.date(2021, 7, 14)),
#  Holiday(name='World Youth Skills Day', date=datetime.date(2021, 7, 15)),
#  Holiday(name='Rural Transit Day', date=datetime.date(2021, 7, 16)),
#  Holiday(name="Tisha B'Av", date=datetime.date(2021, 7, 18)),
#  Holiday(name='Eid al-Adha', date=datetime.date(2021, 7, 20)),
#  Holiday(name='Pioneer Day observed', date=datetime.date(2021, 7, 23)),
#  Holiday(name='Pioneer Day', date=datetime.date(2021, 7, 24)),
#  Holiday(name='World Drowning Prevention Day', date=datetime.date(2021, 7, 25)),
#  Holiday(name='Korean War Veteran Recognition Day', date=datetime.date(2021, 7, 27)),
#  Holiday(name='World Hepatitis Day', date=datetime.date(2021, 7, 28)),
#  Holiday(name='International Day of Friendship', date=datetime.date(2021, 7, 30)),
#  Holiday(name='Colorado Day', date=datetime.date(2021, 8, 1)),
#  Holiday(name='Coast Guard Birthday', date=datetime.date(2021, 8, 4)),
#  Holiday(name='Purple Heart Day', date=datetime.date(2021, 8, 7)),
#  Holiday(name="International Day of the World's Indigenous People", date=datetime.date(2021, 8, 9)),
#  Holiday(name='Muharram', date=datetime.date(2021, 8, 10)),
#  Holiday(name='International Youth Day', date=datetime.date(2021, 8, 12)),
#  Holiday(name='Friday the 13th', date=datetime.date(2021, 8, 13)),
#  Holiday(name='Assumption of Mary', date=datetime.date(2021, 8, 15)),
#  Holiday(name='Bennington Battle Day', date=datetime.date(2021, 8, 16)),
#  Holiday(name='Ashura', date=datetime.date(2021, 8, 19)),
#  Holiday(name='Hawaii Statehood Day', date=datetime.date(2021, 8, 20)),
#  Holiday(name='Raksha Bandhan', date=datetime.date(2021, 8, 21)),
#  Holiday(name='International Day Commemorating the Victims of Acts of Violence Based on Religion or Belief', date=datetime.date(2021, 8, 22)),
#  Holiday(name='International Day for the Remembrance of the Slave Trade and its Abolition', date=datetime.date(2021, 8, 23)),
#  Holiday(name='Susan B. Anthony Day', date=datetime.date(2021, 8, 26)),
#  Holiday(name='Lyndon Baines Johnson Day', date=datetime.date(2021, 8, 27)),
#  Holiday(name='International Day against Nuclear Tests', date=datetime.date(2021, 8, 29)),
#  Holiday(name='International Day of the Victims of Enforced Disappearances', date=datetime.date(2021, 8, 30)),
#  Holiday(name='International Day for People of African Descent', date=datetime.date(2021, 8, 31)),
#  Holiday(name='World Sexual Health Day', date=datetime.date(2021, 9, 4)),
#  Holiday(name='International Day of Charity', date=datetime.date(2021, 9, 5)),
#  Holiday(name='Labor Day', date=datetime.date(2021, 9, 6)),
#  Holiday(name='Rosh Hashana', date=datetime.date(2021, 9, 7)),
#  Holiday(name='International Literacy Day', date=datetime.date(2021, 9, 8)),
#  Holiday(name='International Day to Protect Education from Attack', date=datetime.date(2021, 9, 9)),
#  Holiday(name='Ganesh Chaturthi', date=datetime.date(2021, 9, 10)),
#  Holiday(name='First Responders Day', date=datetime.date(2021, 9, 11)),
#  Holiday(name='International Day for South-South Cooperation', date=datetime.date(2021, 9, 12)),
#  Holiday(name="International Programmers' Day", date=datetime.date(2021, 9, 13)),
#  Holiday(name='International Day of Democracy', date=datetime.date(2021, 9, 15)),
#  Holiday(name='Yom Kippur', date=datetime.date(2021, 9, 16)),
#  Holiday(name='World Patient Safety Day', date=datetime.date(2021, 9, 17)),
#  Holiday(name='International Equal Pay Day', date=datetime.date(2021, 9, 18)),
#  Holiday(name='First Day of Sukkot', date=datetime.date(2021, 9, 21)),
#  Holiday(name='Emancipation Day', date=datetime.date(2021, 9, 22)),
#  Holiday(name='International Day of Sign Languages', date=datetime.date(2021, 9, 23)),
#  Holiday(name='Native American Day', date=datetime.date(2021, 9, 24)),
#  Holiday(name='Public Lands Day', date=datetime.date(2021, 9, 25)),
#  Holiday(name='International Day for the Total Elimination of Nuclear Weapons', date=datetime.date(2021, 9, 26)),
#  Holiday(name='Last Day of Sukkot', date=datetime.date(2021, 9, 27)),
#  Holiday(name='Shmini Atzeret', date=datetime.date(2021, 9, 28)),
#  Holiday(name='Simchat Torah', date=datetime.date(2021, 9, 29)),
#  Holiday(name='World Maritime Day', date=datetime.date(2021, 9, 30)),
#  Holiday(name='International Day of Older Persons', date=datetime.date(2021, 10, 1)),
#  Holiday(name='International Day of Non-Violence', date=datetime.date(2021, 10, 2)),
#  Holiday(name='Feast of St Francis of Assisi', date=datetime.date(2021, 10, 4)),
#  Holiday(name="World Teachers' Day", date=datetime.date(2021, 10, 5)),
#  Holiday(name='Navratri', date=datetime.date(2021, 10, 6)),
#  Holiday(name='World Post Day', date=datetime.date(2021, 10, 9)),
#  Holiday(name='World Mental Health Day', date=datetime.date(2021, 10, 10)),
#  Holiday(name='International Day of the Girl Child', date=datetime.date(2021, 10, 11)),
#  Holiday(name='World Spanish Language Day', date=datetime.date(2021, 10, 12)),
#  Holiday(name='International Day for Natural Disaster Reduction', date=datetime.date(2021, 10, 13)),
#  Holiday(name='Dussehra', date=datetime.date(2021, 10, 14)),
#  Holiday(name='International Day of Rural Women', date=datetime.date(2021, 10, 15)),
#  Holiday(name='World Food Day', date=datetime.date(2021, 10, 16)),
#  Holiday(name='International Day for the Eradication of Poverty', date=datetime.date(2021, 10, 17)),
#  Holiday(name='Alaska Day', date=datetime.date(2021, 10, 18)),
#  Holiday(name="The Prophet's Birthday", date=datetime.date(2021, 10, 19)),
#  Holiday(name='United Nations Day', date=datetime.date(2021, 10, 24)),
#  Holiday(name='World Day for Audiovisual Heritage', date=datetime.date(2021, 10, 27)),
#  Holiday(name='World Stroke Day', date=datetime.date(2021, 10, 29)),
#  Holiday(name='World Cities Day', date=datetime.date(2021, 10, 31)),
#  Holiday(name="All Saints' Day", date=datetime.date(2021, 11, 1)),
#  Holiday(name="All Souls' Day", date=datetime.date(2021, 11, 2)),
#  Holiday(name='Diwali/Deepavali', date=datetime.date(2021, 11, 3)),
#  Holiday(name='Diwali/Deepavali', date=datetime.date(2021, 11, 4)),
#  Holiday(name='World Tsunami Awareness Day', date=datetime.date(2021, 11, 5)),
#  Holiday(name='International Day for Preventing the Exploitation of the Environment in War and Armed Conflict', date=datetime.date(2021, 11, 6)),
#  Holiday(name='New York City Marathon', date=datetime.date(2021, 11, 7)),
#  Holiday(name='Barack Obama Day', date=datetime.date(2021, 11, 8)),
#  Holiday(name='World Science Day for Peace and Development', date=datetime.date(2021, 11, 10)),
#  Holiday(name='Veterans Day', date=datetime.date(2021, 11, 11)),
#  Holiday(name='World Pneumonia Day', date=datetime.date(2021, 11, 12)),
#  Holiday(name='World Diabetes Day', date=datetime.date(2021, 11, 14)),
#  Holiday(name='International Day for Tolerance', date=datetime.date(2021, 11, 16)),
#  Holiday(name='World Prematurity Day', date=datetime.date(2021, 11, 17)),
#  Holiday(name='World Philosophy Day', date=datetime.date(2021, 11, 18)),
#  Holiday(name='World Toilet Day', date=datetime.date(2021, 11, 19)),
#  Holiday(name="Universal Children's Day", date=datetime.date(2021, 11, 20)),
#  Holiday(name='World Day of Remembrance for Road Traffic Victims', date=datetime.date(2021, 11, 21)),
#  Holiday(name='International Day for the Elimination of Violence against Women', date=datetime.date(2021, 11, 25)),
#  Holiday(name='State Holiday', date=datetime.date(2021, 11, 26)),
#  Holiday(name='First Sunday of Advent', date=datetime.date(2021, 11, 28)),
#  Holiday(name='Chanukah/Hanukkah (first day)', date=datetime.date(2021, 11, 29)),
#  Holiday(name='Day of Remembrance for all Victims of Chemical Warfare', date=datetime.date(2021, 11, 30)),
#  Holiday(name='World AIDS Day', date=datetime.date(2021, 12, 1)),
#  Holiday(name='International Day for the Abolition of Slavery', date=datetime.date(2021, 12, 2)),
#  Holiday(name='International Day of Persons with Disabilities', date=datetime.date(2021, 12, 3)),
#  Holiday(name='International Day of Banks', date=datetime.date(2021, 12, 4)),
#  Holiday(name='International Volunteer Day for Economic and Social Development', date=datetime.date(2021, 12, 5)),
#  Holiday(name='Last Day of Chanukah', date=datetime.date(2021, 12, 6)),
#  Holiday(name='International Civil Aviation Day', date=datetime.date(2021, 12, 7)),
#  Holiday(name='Feast of the Immaculate Conception', date=datetime.date(2021, 12, 8)),
#  Holiday(name='International Anti-Corruption Day', date=datetime.date(2021, 12, 9)),
#  Holiday(name='Human Rights Day', date=datetime.date(2021, 12, 10)),
#  Holiday(name='International Mountain Day', date=datetime.date(2021, 12, 11)),
#  Holiday(name='International Day of Neutrality', date=datetime.date(2021, 12, 12)),
#  Holiday(name='National Guard Birthday', date=datetime.date(2021, 12, 13)),
#  Holiday(name="Asarah B'Tevet", date=datetime.date(2021, 12, 14)),
#  Holiday(name='Bill of Rights Day', date=datetime.date(2021, 12, 15)),
#  Holiday(name='Pan American Aviation Day', date=datetime.date(2021, 12, 17)),
#  Holiday(name='International Migrants Day', date=datetime.date(2021, 12, 18)),
#  Holiday(name='International Human Solidarity Day', date=datetime.date(2021, 12, 20)),
#  Holiday(name='December Solstice', date=datetime.date(2021, 12, 21)),
#  Holiday(name="Washington's Birthday", date=datetime.date(2021, 12, 23)),
#  Holiday(name='Christmas Day (substitute)', date=datetime.date(2021, 12, 24)),
#  Holiday(name='Christmas Day', date=datetime.date(2021, 12, 25)),
#  Holiday(name='Kwanzaa (first day)', date=datetime.date(2021, 12, 26)),
#  Holiday(name='International Day of Epidemic Preparedness', date=datetime.date(2021, 12, 27)),
#  Holiday(name='New Year Holiday', date=datetime.date(2021, 12, 30)),
#  Holiday(name="New Year's Day (substitute)", date=datetime.date(2021, 12, 31)),
#  Holiday(name="New Year's Day", date=datetime.date(2022, 1, 1)),
#  Holiday(name="New Year's Day (substitute)", date=datetime.date(2022, 1, 3)),
#  Holiday(name='World Braille Day', date=datetime.date(2022, 1, 4)),
#  Holiday(name='Epiphany', date=datetime.date(2022, 1, 6)),
#  Holiday(name='Orthodox Christmas Day', date=datetime.date(2022, 1, 7)),
#  Holiday(name='Battle of New Orleans', date=datetime.date(2022, 1, 8)),
#  Holiday(name='Stephen Foster Memorial Day', date=datetime.date(2022, 1, 13)),
#  Holiday(name='Orthodox New Year', date=datetime.date(2022, 1, 14)),
#  Holiday(name='World Religion Day', date=datetime.date(2022, 1, 16)),
#  Holiday(name="Tu Bishvat/Tu B'Shevat", date=datetime.date(2022, 1, 17)),
#  Holiday(name="Robert E. Lee's Birthday", date=datetime.date(2022, 1, 19)),
#  Holiday(name='International Day of Education', date=datetime.date(2022, 1, 24)),
#  Holiday(name='International Customs Day', date=datetime.date(2022, 1, 26)),
#  Holiday(name='International Day of Commemoration in Memory of the Victims of the Holocaust', date=datetime.date(2022, 1, 27)),
#  Holiday(name='Kansas Day', date=datetime.date(2022, 1, 29)),
#  Holiday(name='World Leprosy Day', date=datetime.date(2022, 1, 30)),
#  Holiday(name='National Freedom Day', date=datetime.date(2022, 2, 1)),
#  Holiday(name='World Wetlands Day', date=datetime.date(2022, 2, 2)),
#  Holiday(name='International Day of Human Fraternity', date=datetime.date(2022, 2, 4)),
#  Holiday(name='International Day of Zero Tolerance for Female Genital Mutilation', date=datetime.date(2022, 2, 6)),
#  Holiday(name='World Pulses Day', date=datetime.date(2022, 2, 10)),
#  Holiday(name='International Day of Women and Girls in Science', date=datetime.date(2022, 2, 11)),
#  Holiday(name="Lincoln's Birthday", date=datetime.date(2022, 2, 12)),
#  Holiday(name='World Radio Day', date=datetime.date(2022, 2, 13)),
#  Holiday(name="Valentine's Day", date=datetime.date(2022, 2, 14)),
#  Holiday(name="Susan B. Anthony's Birthday", date=datetime.date(2022, 2, 15)),
#  Holiday(name='Elizabeth Peratrovich Day', date=datetime.date(2022, 2, 16)),
#  Holiday(name='World Day of Social Justice', date=datetime.date(2022, 2, 20)),
#  Holiday(name='International Mother Language Day', date=datetime.date(2022, 2, 21)),
#  Holiday(name='African-American Scientist and Inventor Day', date=datetime.date(2022, 2, 25)),
#  Holiday(name='Maha Shivaratri', date=datetime.date(2022, 2, 28)),
#  Holiday(name="Isra and Mi'raj", date=datetime.date(2022, 3, 1)),
#  Holiday(name='Ash Wednesday', date=datetime.date(2022, 3, 2)),
#  Holiday(name='World Wildlife Day', date=datetime.date(2022, 3, 3)),
#  Holiday(name='Casimir Pulaski Day', date=datetime.date(2022, 3, 4)),
#  Holiday(name='Casimir Pulaski Day', date=datetime.date(2022, 3, 7)),
#  Holiday(name="International Women's Day", date=datetime.date(2022, 3, 8)),
#  Holiday(name='International Day of Women Judges', date=datetime.date(2022, 3, 10)),
#  Holiday(name='Daylight Saving Time starts', date=datetime.date(2022, 3, 13)),
#  Holiday(name='Purim', date=datetime.date(2022, 3, 17)),
#  Holiday(name='Holi', date=datetime.date(2022, 3, 18)),
#  Holiday(name='French Language Day', date=datetime.date(2022, 3, 20)),
#  Holiday(name='International Day for the Elimination of Racial Discrimination', date=datetime.date(2022, 3, 21)),
#  Holiday(name='World Water Day', date=datetime.date(2022, 3, 22)),
#  Holiday(name='World Meteorological Day', date=datetime.date(2022, 3, 23)),
#  Holiday(name='World Tuberculosis Day', date=datetime.date(2022, 3, 24)),
#  Holiday(name='International Day of Remembrance of Slavery Victims and the Transatlantic Slave Trade', date=datetime.date(2022, 3, 25)),
#  Holiday(name='Earth Hour', date=datetime.date(2022, 3, 26)),
#  Holiday(name="Seward's Day", date=datetime.date(2022, 3, 28)),
#  Holiday(name='National Vietnam War Veterans Day', date=datetime.date(2022, 3, 29)),
#  Holiday(name='Wyoming Veterans Welcome Home Day', date=datetime.date(2022, 3, 30)),
#  Holiday(name='César Chávez Day', date=datetime.date(2022, 3, 31)),
#  Holiday(name="April Fool's Day", date=datetime.date(2022, 4, 1)),
#  Holiday(name='World Autism Awareness Day', date=datetime.date(2022, 4, 2)),
#  Holiday(name='Ramadan Starts', date=datetime.date(2022, 4, 3)),
#  Holiday(name="United Nations' Mine Awareness Day", date=datetime.date(2022, 4, 4)),
#  Holiday(name='International Day of Conscience', date=datetime.date(2022, 4, 5)),
#  Holiday(name='International Day of Sport for Development and Peace', date=datetime.date(2022, 4, 6)),
#  Holiday(name="United Nations' World Health Day", date=datetime.date(2022, 4, 7)),
#  Holiday(name='Palm Sunday', date=datetime.date(2022, 4, 10)),
#  Holiday(name='International Day of Human Space Flight', date=datetime.date(2022, 4, 12)),
#  Holiday(name="Thomas Jefferson's Birthday", date=datetime.date(2022, 4, 13)),
#  Holiday(name='Maundy Thursday', date=datetime.date(2022, 4, 14)),
#  Holiday(name='Passover Eve', date=datetime.date(2022, 4, 15)),
#  Holiday(name='Holy Saturday', date=datetime.date(2022, 4, 16)),
#  Holiday(name='Easter Sunday', date=datetime.date(2022, 4, 17)),
#  Holiday(name='International Day for Monuments and Sites', date=datetime.date(2022, 4, 18)),
#  Holiday(name='Chinese Language Day', date=datetime.date(2022, 4, 20)),
#  Holiday(name='World Creativity and Innovation Day', date=datetime.date(2022, 4, 21)),
#  Holiday(name='Orthodox Good Friday', date=datetime.date(2022, 4, 22)),
#  Holiday(name='Last Day of Passover', date=datetime.date(2022, 4, 23)),
#  Holiday(name='Orthodox Easter', date=datetime.date(2022, 4, 24)),
#  Holiday(name='Orthodox Easter Monday', date=datetime.date(2022, 4, 25)),
#  Holiday(name='World Intellectual Property Day', date=datetime.date(2022, 4, 26)),
#  Holiday(name='Administrative Professionals Day', date=datetime.date(2022, 4, 27)),
#  Holiday(name='Yom HaShoah', date=datetime.date(2022, 4, 28)),
#  Holiday(name='Arbor Day', date=datetime.date(2022, 4, 29)),
#  Holiday(name='International Jazz Day', date=datetime.date(2022, 4, 30)),
#  Holiday(name='International Family Equality Day', date=datetime.date(2022, 5, 1)),
#  Holiday(name='Eid al-Fitr', date=datetime.date(2022, 5, 2)),
#  Holiday(name='World Press Freedom Day', date=datetime.date(2022, 5, 3)),
#  Holiday(name='Kent State Shootings Remembrance', date=datetime.date(2022, 5, 4)),
#  Holiday(name="Yom Ha'atzmaut", date=datetime.date(2022, 5, 5)),
# ...
#  Holiday(name='Orthodox Christmas Day', date=datetime.date(2023, 1, 7)),
#  Holiday(name='Battle of New Orleans', date=datetime.date(2023, 1, 8)),
#  Holiday(name='Friday the 13th', date=datetime.date(2023, 1, 13)),
#  Holiday(name='Orthodox New Year', date=datetime.date(2023, 1, 14)),
#  Holiday(name='World Religion Day', date=datetime.date(2023, 1, 15)),
#  Holiday(name='Martin Luther King Jr. Day', date=datetime.date(2023, 1, 16)),
#  Holiday(name="Robert E. Lee's Birthday", date=datetime.date(2023, 1, 19)),
#  Holiday(name='Lunar New Year', date=datetime.date(2023, 1, 22)),
#  Holiday(name='International Day of Education', date=datetime.date(2023, 1, 24)),
#  Holiday(name='International Customs Day', date=datetime.date(2023, 1, 26)),
#  Holiday(name='International Day of Commemoration in Memory of the Victims of the Holocaust', date=datetime.date(2023, 1, 27)),
#  Holiday(name='World Leprosy Day', date=datetime.date(2023, 1, 29)),
#  Holiday(name='National Freedom Day', date=datetime.date(2023, 2, 1)),
#  Holiday(name='World Wetlands Day', date=datetime.date(2023, 2, 2)),
#  Holiday(name='National Wear Red Day', date=datetime.date(2023, 2, 3)),
#  Holiday(name='International Day of Human Fraternity', date=datetime.date(2023, 2, 4)),
#  Holiday(name="Tu Bishvat/Tu B'Shevat", date=datetime.date(2023, 2, 6)),
#  Holiday(name='World Pulses Day', date=datetime.date(2023, 2, 10)),
#  Holiday(name='International Day of Women and Girls in Science', date=datetime.date(2023, 2, 11)),
#  Holiday(name="Lincoln's Birthday", date=datetime.date(2023, 2, 12)),
#  Holiday(name='World Radio Day', date=datetime.date(2023, 2, 13)),
#  Holiday(name="Valentine's Day", date=datetime.date(2023, 2, 14)),
#  Holiday(name="Susan B. Anthony's Birthday", date=datetime.date(2023, 2, 15)),
#  Holiday(name='Elizabeth Peratrovich Day', date=datetime.date(2023, 2, 16)),
#  Holiday(name='Maha Shivaratri', date=datetime.date(2023, 2, 18)),
#  Holiday(name='World Day of Social Justice', date=datetime.date(2023, 2, 20)),
#  Holiday(name='International Mother Language Day', date=datetime.date(2023, 2, 21)),
#  Holiday(name='Ash Wednesday', date=datetime.date(2023, 2, 22)),
#  Holiday(name='African-American Scientist and Inventor Day', date=datetime.date(2023, 2, 25)),
#  Holiday(name='Linus Pauling Day', date=datetime.date(2023, 2, 28)),
#  Holiday(name='Zero Discrimination Day', date=datetime.date(2023, 3, 1)),
#  Holiday(name='Texas Independence Day', date=datetime.date(2023, 3, 2)),
#  Holiday(name='World Wildlife Day', date=datetime.date(2023, 3, 3)),
#  Holiday(name='Casimir Pulaski Day', date=datetime.date(2023, 3, 4)),
#  Holiday(name='Casimir Pulaski Day', date=datetime.date(2023, 3, 6)),
#  Holiday(name='Holi', date=datetime.date(2023, 3, 7)),
#  Holiday(name="International Women's Day", date=datetime.date(2023, 3, 8)),
#  Holiday(name='World Kidney Day', date=datetime.date(2023, 3, 9)),
#  Holiday(name='International Day of Women Judges', date=datetime.date(2023, 3, 10)),
#  Holiday(name='Daylight Saving Time starts', date=datetime.date(2023, 3, 12)),
#  Holiday(name="St. Patrick's Day", date=datetime.date(2023, 3, 17)),
#  Holiday(name='French Language Day', date=datetime.date(2023, 3, 20)),
#  Holiday(name='International Day for the Elimination of Racial Discrimination', date=datetime.date(2023, 3, 21)),
#  Holiday(name='World Water Day', date=datetime.date(2023, 3, 22)),
#  Holiday(name='Ramadan Starts', date=datetime.date(2023, 3, 23)),
#  Holiday(name='World Tuberculosis Day', date=datetime.date(2023, 3, 24)),
#  Holiday(name='International Day of Remembrance of Slavery Victims and the Transatlantic Slave Trade', date=datetime.date(2023, 3, 25)),
#  Holiday(name='Prince Jonah Kuhio Kalanianaole Day', date=datetime.date(2023, 3, 26)),
#  Holiday(name='Prince Jonah Kuhio Kalanianaole Day observed', date=datetime.date(2023, 3, 27)),
#  Holiday(name='National Vietnam War Veterans Day', date=datetime.date(2023, 3, 29)),
#  Holiday(name='Wyoming Veterans Welcome Home Day', date=datetime.date(2023, 3, 30)),
#  Holiday(name='César Chávez Day', date=datetime.date(2023, 3, 31)),
#  Holiday(name="April Fool's Day", date=datetime.date(2023, 4, 1)),
#  Holiday(name='Palm Sunday', date=datetime.date(2023, 4, 2)),
#  Holiday(name='Pascua Florida Day observed', date=datetime.date(2023, 4, 3)),
#  Holiday(name="United Nations' Mine Awareness Day", date=datetime.date(2023, 4, 4)),
#  Holiday(name='Passover Eve', date=datetime.date(2023, 4, 5)),
#  Holiday(name='Maundy Thursday', date=datetime.date(2023, 4, 6)),
#  Holiday(name="United Nations' World Health Day", date=datetime.date(2023, 4, 7)),
#  Holiday(name='Holy Saturday', date=datetime.date(2023, 4, 8)),
#  Holiday(name='Easter Sunday', date=datetime.date(2023, 4, 9)),
#  Holiday(name='Easter Monday', date=datetime.date(2023, 4, 10)),
#  Holiday(name='International Day of Human Space Flight', date=datetime.date(2023, 4, 12)),
#  Holiday(name='Last Day of Passover', date=datetime.date(2023, 4, 13)),
#  Holiday(name='Orthodox Good Friday', date=datetime.date(2023, 4, 14)),
#  Holiday(name='Orthodox Holy Saturday', date=datetime.date(2023, 4, 15)),
#  Holiday(name='Orthodox Easter', date=datetime.date(2023, 4, 16)),
#  Holiday(name='Lailat al-Qadr', date=datetime.date(2023, 4, 17)),
#  Holiday(name='Yom HaShoah', date=datetime.date(2023, 4, 18)),
#  Holiday(name='Chinese Language Day', date=datetime.date(2023, 4, 20)),
#  Holiday(name='World Creativity and Innovation Day', date=datetime.date(2023, 4, 21)),
#  Holiday(name='Eid al-Fitr (Tentative Date)', date=datetime.date(2023, 4, 22)),
#  Holiday(name='World Book and Copyright Day', date=datetime.date(2023, 4, 23)),
#  Holiday(name='International Day of Multilateralism and Diplomacy for Peace', date=datetime.date(2023, 4, 24)),
#  Holiday(name="International Delegate's Day", date=datetime.date(2023, 4, 25)),
#  Holiday(name="Yom Ha'atzmaut", date=datetime.date(2023, 4, 26)),
#  Holiday(name='International Girls in ICT Day', date=datetime.date(2023, 4, 27)),
#  Holiday(name='World Day for Safety and Health at Work', date=datetime.date(2023, 4, 28)),
#  Holiday(name='International Jazz Day', date=datetime.date(2023, 4, 30)),
#  Holiday(name='Law Day', date=datetime.date(2023, 5, 1)),
#  Holiday(name='World Tuna Day', date=datetime.date(2023, 5, 2)),
#  Holiday(name='World Press Freedom Day', date=datetime.date(2023, 5, 3)),
#  Holiday(name='Kent State Shootings Remembrance', date=datetime.date(2023, 5, 4)),
#  Holiday(name='Day of Vesak', date=datetime.date(2023, 5, 5)),
#  Holiday(name='Kentucky Derby', date=datetime.date(2023, 5, 6)),
#  Holiday(name='International Family Equality Day', date=datetime.date(2023, 5, 7)),
#  Holiday(name='Time of Remembrance and Reconciliation for Those Who Lost Their Lives during the Second World War', date=datetime.date(2023, 5, 8)),
#  Holiday(name='Lag BaOmer', date=datetime.date(2023, 5, 9)),
#  Holiday(name='International Day of Argania', date=datetime.date(2023, 5, 10)),
#  Holiday(name='International Nurses Day', date=datetime.date(2023, 5, 12)),
#  Holiday(name='World Migratory Bird Day', date=datetime.date(2023, 5, 13)),
#  Holiday(name="Mother's Day", date=datetime.date(2023, 5, 14)),
#  Holiday(name='International Day of Families', date=datetime.date(2023, 5, 15)),
#  Holiday(name='International Day of Living Together in Peace', date=datetime.date(2023, 5, 16)),
#  Holiday(name='World Telecommunication and Information Society Day', date=datetime.date(2023, 5, 17)),
#  Holiday(name='Ascension Day', date=datetime.date(2023, 5, 18)),
#  Holiday(name='National Defense Transportation Day', date=datetime.date(2023, 5, 19)),
#  Holiday(name='World Bee Day', date=datetime.date(2023, 5, 20)),
#  Holiday(name='World Day for Cultural Diversity for Dialogue and Development', date=datetime.date(2023, 5, 21)),
#  Holiday(name='International Day for Biological Diversity', date=datetime.date(2023, 5, 22)),
#  Holiday(name='International Day to End Obstetric Fistula', date=datetime.date(2023, 5, 23)),
#  Holiday(name='Emergency Medical Services for Children Day', date=datetime.date(2023, 5, 24)),
#  Holiday(name='African Liberation Day', date=datetime.date(2023, 5, 25)),
#  Holiday(name='Shavuot', date=datetime.date(2023, 5, 26)),
#  Holiday(name='Pentecost', date=datetime.date(2023, 5, 28)),
#  Holiday(name='Whit Monday', date=datetime.date(2023, 5, 29)),
#  Holiday(name='World No Tobacco Day', date=datetime.date(2023, 5, 31)),
#  Holiday(name='Global Day of Parents', date=datetime.date(2023, 6, 1)),
#  Holiday(name='World Bicycle Day', date=datetime.date(2023, 6, 3)),
#  Holiday(name='Trinity Sunday', date=datetime.date(2023, 6, 4)),
#  Holiday(name='World Environment Day', date=datetime.date(2023, 6, 5)),
#  Holiday(name='Day of the Russian Language', date=datetime.date(2023, 6, 6)),
#  Holiday(name='World Food Safety Day', date=datetime.date(2023, 6, 7)),
#  Holiday(name='Corpus Christi', date=datetime.date(2023, 6, 8)),
#  Holiday(name='Belmont Stakes', date=datetime.date(2023, 6, 10)),
#  Holiday(name='Kamehameha Day', date=datetime.date(2023, 6, 11)),
#  Holiday(name='World Day Against Child Labour', date=datetime.date(2023, 6, 12)),
#  Holiday(name='International Albinism Awareness Day', date=datetime.date(2023, 6, 13)),
#  Holiday(name='World Blood Donor Day', date=datetime.date(2023, 6, 14)),
#  Holiday(name='World Elder Abuse Awareness Day', date=datetime.date(2023, 6, 15)),
#  Holiday(name='International Day of Family Remittances', date=datetime.date(2023, 6, 16)),
#  Holiday(name='World Day to Combat Desertification and Drought', date=datetime.date(2023, 6, 17)),
#  Holiday(name='Sustainable Gastronomy Day', date=datetime.date(2023, 6, 18)),
#  Holiday(name='International Day for the Elimination of Sexual Violence in Conflict', date=datetime.date(2023, 6, 19)),
#  Holiday(name='World Refugee Day', date=datetime.date(2023, 6, 20)),
#  Holiday(name='International Day of Yoga', date=datetime.date(2023, 6, 21)),
#  Holiday(name='Public Service Day', date=datetime.date(2023, 6, 23)),
#  Holiday(name='Day of the Seafarer', date=datetime.date(2023, 6, 25)),
#  Holiday(name='International Day Against Drug Abuse and Illicit Trafficking', date=datetime.date(2023, 6, 26)),
#  Holiday(name='Micro-, Small and Medium-sized Enterprises Day', date=datetime.date(2023, 6, 27)),
#  Holiday(name='Carolina Day', date=datetime.date(2023, 6, 28)),
#  Holiday(name='Eid al-Adha (Tentative Date)', date=datetime.date(2023, 6, 29)),
#  Holiday(name='International Asteroid Day', date=datetime.date(2023, 6, 30)),
#  Holiday(name='International Day of Cooperatives', date=datetime.date(2023, 7, 1)),
#  Holiday(name='Independence Day', date=datetime.date(2023, 7, 4)),
#  Holiday(name='World Population Day', date=datetime.date(2023, 7, 11)),
#  Holiday(name='Nathan Bedford Forrest Day', date=datetime.date(2023, 7, 13)),
#  Holiday(name='Bastille Day', date=datetime.date(2023, 7, 14)),
#  Holiday(name='World Youth Skills Day', date=datetime.date(2023, 7, 15)),
#  Holiday(name='Rural Transit Day', date=datetime.date(2023, 7, 16)),
#  Holiday(name='Nelson Mandela Day', date=datetime.date(2023, 7, 18)),
#  Holiday(name='Muharram (Tentative Date)', date=datetime.date(2023, 7, 19)),
#  Holiday(name='World Chess Day', date=datetime.date(2023, 7, 20)),
#  Holiday(name="Parents' Day", date=datetime.date(2023, 7, 23)),
#  Holiday(name='Pioneer Day', date=datetime.date(2023, 7, 24)),
#  Holiday(name='World Drowning Prevention Day', date=datetime.date(2023, 7, 25)),
#  Holiday(name="Tisha B'Av", date=datetime.date(2023, 7, 27)),
#  Holiday(name='Ashura (Tentative Date)', date=datetime.date(2023, 7, 28)),
#  Holiday(name='International Day of Friendship', date=datetime.date(2023, 7, 30)),
#  Holiday(name='Colorado Day', date=datetime.date(2023, 8, 1)),
#  Holiday(name='Coast Guard Birthday', date=datetime.date(2023, 8, 4)),
#  Holiday(name='American Family Day', date=datetime.date(2023, 8, 6)),
#  Holiday(name='Purple Heart Day', date=datetime.date(2023, 8, 7)),
#  Holiday(name="International Day of the World's Indigenous People", date=datetime.date(2023, 8, 9)),
#  Holiday(name='International Youth Day', date=datetime.date(2023, 8, 12)),
#  Holiday(name='Victory Day', date=datetime.date(2023, 8, 14)),
#  Holiday(name='Assumption of Mary', date=datetime.date(2023, 8, 15)),
#  Holiday(name='Bennington Battle Day', date=datetime.date(2023, 8, 16)),
#  Holiday(name='Hawaii Statehood Day', date=datetime.date(2023, 8, 18)),
#  Holiday(name='World Humanitarian Day', date=datetime.date(2023, 8, 19)),
#  Holiday(name='National Navajo Code Talkers Day', date=datetime.date(2023, 8, 20)),
#  Holiday(name='International Day of Remembrance of and Tribute to the Victims of Terrorism', date=datetime.date(2023, 8, 21)),
#  Holiday(name='International Day Commemorating the Victims of Acts of Violence Based on Religion or Belief', date=datetime.date(2023, 8, 22)),
#  Holiday(name='International Day for the Remembrance of the Slave Trade and its Abolition', date=datetime.date(2023, 8, 23)),
#  Holiday(name='Susan B. Anthony Day', date=datetime.date(2023, 8, 26)),
#  Holiday(name='Lyndon Baines Johnson Day', date=datetime.date(2023, 8, 27)),
#  Holiday(name='International Day against Nuclear Tests', date=datetime.date(2023, 8, 29)),
#  Holiday(name='Raksha Bandhan', date=datetime.date(2023, 8, 30)),
#  Holiday(name='International Day for People of African Descent', date=datetime.date(2023, 8, 31)),
#  Holiday(name='World Sexual Health Day', date=datetime.date(2023, 9, 4)),
#  Holiday(name='International Day of Charity', date=datetime.date(2023, 9, 5)),
#  Holiday(name='International Day of Clean Air for Blue Skies', date=datetime.date(2023, 9, 7)),
#  Holiday(name='International Literacy Day', date=datetime.date(2023, 9, 8)),
#  Holiday(name='International Day to Protect Education from Attack', date=datetime.date(2023, 9, 9)),
#  Holiday(name='World Suicide Prevention Day', date=datetime.date(2023, 9, 10)),
#  Holiday(name='First Responders Day', date=datetime.date(2023, 9, 11)),
#  Holiday(name='International Day for South-South Cooperation', date=datetime.date(2023, 9, 12)),
#  Holiday(name="International Programmers' Day", date=datetime.date(2023, 9, 13)),
#  Holiday(name='International Day of Democracy', date=datetime.date(2023, 9, 15)),
#  Holiday(name='Rosh Hashana', date=datetime.date(2023, 9, 16)),
#  Holiday(name='World Patient Safety Day', date=datetime.date(2023, 9, 17)),
#  Holiday(name='Ganesh Chaturthi', date=datetime.date(2023, 9, 18)),
#  Holiday(name='International Day of Peace', date=datetime.date(2023, 9, 21)),
#  Holiday(name='Emancipation Day', date=datetime.date(2023, 9, 22)),
#  Holiday(name='International Day of Sign Languages', date=datetime.date(2023, 9, 23)),
#  Holiday(name="Gold Star Mother's Day", date=datetime.date(2023, 9, 24)),
#  Holiday(name='Yom Kippur', date=datetime.date(2023, 9, 25)),
#  Holiday(name='International Day for the Total Elimination of Nuclear Weapons', date=datetime.date(2023, 9, 26)),
#  Holiday(name="The Prophet's Birthday", date=datetime.date(2023, 9, 27)),
#  Holiday(name='World Maritime Day', date=datetime.date(2023, 9, 28)),
#  Holiday(name='International Day of Awareness of Food Loss and Waste', date=datetime.date(2023, 9, 29)),
#  Holiday(name='First Day of Sukkot', date=datetime.date(2023, 9, 30)),
#  Holiday(name='International Day of Older Persons', date=datetime.date(2023, 10, 1)),
#  Holiday(name='World Habitat Day', date=datetime.date(2023, 10, 2)),
#  Holiday(name='Feast of St Francis of Assisi', date=datetime.date(2023, 10, 4)),
#  Holiday(name="World Teachers' Day", date=datetime.date(2023, 10, 5)),
#  Holiday(name='Last Day of Sukkot', date=datetime.date(2023, 10, 6)),
#  Holiday(name='Shmini Atzeret', date=datetime.date(2023, 10, 7)),
#  Holiday(name='Simchat Torah', date=datetime.date(2023, 10, 8)),
#  Holiday(name='World Post Day', date=datetime.date(2023, 10, 9)),
#  Holiday(name='World Mental Health Day', date=datetime.date(2023, 10, 10)),
#  Holiday(name='International Day for Natural Disaster Reduction', date=datetime.date(2023, 10, 11)),
#  Holiday(name='World Spanish Language Day', date=datetime.date(2023, 10, 12)),
#  Holiday(name='Friday the 13th', date=datetime.date(2023, 10, 13)),
#  Holiday(name="Robert E. Lee's Birthday", date=datetime.date(2023, 10, 14)),
#  ...]

# %%
hol_name = input("Holiday Name: ").strip()
filt_hol = list(filter(lambda hol: hol.name == hol_name, hol_list.inner_holidays))
print(filt_hol)
for hol in filt_hol:
    clean = str(hol)
    print(clean)
hol_year = int(input("Holiday Year: ").strip())
chosen_hol = list(filter(lambda hol: hol.date.isocalendar().year == hol_year, filt_hol))
chosen_hol
# index = hol_list.inner_holidays.index(filt_hol[0])
# index
# Out:
# [Holiday(name='International Day for the Elimination of Violence against Women', date=datetime.date(2020, 11, 25)), Holiday(name='International Day for the Elimination of Violence against Women', date=datetime.date(2021, 11, 25)), Holiday(name='International Day for the Elimination of Violence against Women', date=datetime.date(2022, 11, 25)), Holiday(name='International Day for the Elimination of Violence against Women', date=datetime.date(2023, 11, 25)), Holiday(name='International Day for the Elimination of Violence against Women', date=datetime.date(2024, 11, 25))]
# International Day for the Elimination of Violence against Women (2020-11-25)
# International Day for the Elimination of Violence against Women (2021-11-25)
# International Day for the Elimination of Violence against Women (2022-11-25)
# International Day for the Elimination of Violence against Women (2023-11-25)
# International Day for the Elimination of Violence against Women (2024-11-25)
# [Holiday(name='International Day for the Elimination of Violence against Women', date=datetime.date(2020, 11, 25))]
